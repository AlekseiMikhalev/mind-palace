# %% [markdown]
# Source: https://tts.readthedocs.io/en/latest/tutorial_for_nervous_beginners.html#training-a-tts-model
#
# https://github.com/neonsecret/TTS-With-Voice-Cloning-Multilang

# %%
# !pip install TTS
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting TTS
#   Downloading TTS-0.11.1-cp38-cp38-manylinux1_x86_64.whl (604 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 604.1/604.1 KB 38.8 MB/s eta 0:00:00
# Collecting g2pkk>=0.1.1
#   Downloading g2pkk-0.1.2-py3-none-any.whl (25 kB)
# Collecting umap-learn==0.5.1
#   Downloading umap-learn-0.5.1.tar.gz (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 KB 11.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting mecab-python3==1.0.5
#   Downloading mecab_python3-1.0.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (577 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 577.3/577.3 KB 50.3 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from TTS) (6.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from TTS) (3.5.3)
# Collecting librosa==0.8.0
#   Downloading librosa-0.8.0.tar.gz (183 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 KB 24.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting unidic-lite==1.0.8
#   Downloading unidic-lite-1.0.8.tar.gz (47.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 MB 16.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from TTS) (23.0)
# Collecting pysbd
#   Downloading pysbd-0.3.4-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 KB 10.2 MB/s eta 0:00:00
# Collecting gruut[de]==2.2.3
#   Downloading gruut-2.2.3.tar.gz (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 KB 10.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.8/dist-packages (from TTS) (1.13.1+cu116)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from TTS) (4.64.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (from TTS) (3.7)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.8/dist-packages (from TTS) (0.12.1)
# Collecting jamo
#   Downloading jamo-0.4.1-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: jieba in /usr/local/lib/python3.8/dist-packages (from TTS) (0.42.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from TTS) (1.3.5)
# Collecting trainer==0.0.20
#   Downloading trainer-0.0.20-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 KB 6.1 MB/s eta 0:00:00
# Collecting anyascii
#   Downloading anyascii-0.3.1-py3-none-any.whl (287 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.5/287.5 KB 35.1 MB/s eta 0:00:00
# Collecting cython==0.29.28
#   Downloading Cython-0.29.28-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 88.3 MB/s eta 0:00:00
# Collecting inflect==5.6.0
#   Downloading inflect-5.6.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.8/dist-packages (from TTS) (0.13.1+cu116)
# Requirement already satisfied: flask in /usr/local/lib/python3.8/dist-packages (from TTS) (2.2.3)
# Collecting pypinyin
#   Downloading pypinyin-0.48.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 79.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec>=2021.04.0 in /usr/local/lib/python3.8/dist-packages (from TTS) (2023.1.0)
# Collecting coqpit>=0.0.16
#   Downloading coqpit-0.0.17-py3-none-any.whl (13 kB)
# Collecting numpy==1.21.6
#   Downloading numpy-1.21.6-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 95.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from TTS) (1.10.1)
# Collecting numba==0.55.1
#   Downloading numba-0.55.1-1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 78.0 MB/s eta 0:00:00
# Requirement already satisfied: Babel<3.0.0,>=2.8.0 in /usr/local/lib/python3.8/dist-packages (from gruut[de]==2.2.3->TTS) (2.12.1)
# Collecting dateparser~=1.1.0
#   Downloading dateparser-1.1.7-py2.py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.4/293.4 KB 35.9 MB/s eta 0:00:00
# Collecting gruut-ipa<1.0,>=0.12.0
#   Downloading gruut-ipa-0.13.0.tar.gz (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 KB 14.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gruut_lang_en~=2.0.0
#   Downloading gruut_lang_en-2.0.0.tar.gz (15.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 65.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jsonlines~=1.2.0
#   Downloading jsonlines-1.2.0-py2.py3-none-any.whl (7.6 kB)
# Collecting networkx<3.0.0,>=2.5.0
#   Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 55.8 MB/s eta 0:00:00
# Collecting num2words<1.0.0,>=0.5.10
#   Downloading num2words-0.5.12-py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 KB 17.0 MB/s eta 0:00:00
# Collecting python-crfsuite~=0.9.7
#   Downloading python_crfsuite-0.9.9-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 59.4 MB/s eta 0:00:00
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.8/dist-packages (from gruut[de]==2.2.3->TTS) (5.12.0)
# Collecting gruut_lang_de~=2.0.0
#   Downloading gruut_lang_de-2.0.0.tar.gz (18.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 91.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from librosa==0.8.0->TTS) (3.0.0)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from librosa==0.8.0->TTS) (1.2.1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.8/dist-packages (from librosa==0.8.0->TTS) (1.2.0)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from librosa==0.8.0->TTS) (4.4.2)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from librosa==0.8.0->TTS) (0.4.2)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.8/dist-packages (from librosa==0.8.0->TTS) (1.7.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba==0.55.1->TTS) (57.4.0)
# Collecting llvmlite<0.39,>=0.38.0rc1
#   Downloading llvmlite-0.38.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 17.4 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.8/dist-packages (from trainer==0.0.20->TTS) (5.4.8)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from trainer==0.0.20->TTS) (3.19.6)
# Collecting tensorboardX
#   Downloading tensorboardX-2.6-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 KB 16.3 MB/s eta 0:00:00
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.8.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 69.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.8/dist-packages (from soundfile->TTS) (1.15.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.7->TTS) (4.5.0)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.8/dist-packages (from flask->TTS) (3.1.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.8/dist-packages (from flask->TTS) (2.2.3)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /usr/local/lib/python3.8/dist-packages (from flask->TTS) (6.0.0)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.8/dist-packages (from flask->TTS) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.8/dist-packages (from flask->TTS) (8.1.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib->TTS) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->TTS) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->TTS) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->TTS) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->TTS) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->TTS) (8.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk->TTS) (2022.6.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->TTS) (2022.7.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.0->soundfile->TTS) (2.21)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.8/dist-packages (from dateparser~=1.1.0->gruut[de]==2.2.3->TTS) (1.5.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=3.6.0->flask->TTS) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from Jinja2>=3.0->flask->TTS) (2.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from jsonlines~=1.2.0->gruut[de]==2.2.3->TTS) (1.15.0)
# Collecting docopt>=0.6.2
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.8/dist-packages (from pooch>=1.0->librosa==0.8.0->TTS) (3.0.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.8/dist-packages (from pooch>=1.0->librosa==0.8.0->TTS) (2.25.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa==0.8.0->TTS) (3.1.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.8.0->TTS) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.8.0->TTS) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.8.0->TTS) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.8.0->TTS) (4.0.0)
# Building wheels for collected packages: librosa, umap-learn, unidic-lite, gruut-ipa, gruut_lang_de, gruut_lang_en, pynndescent, gruut, docopt
#   Building wheel for librosa (setup.py) ... done
#   Created wheel for librosa: filename=librosa-0.8.0-py3-none-any.whl size=201396 sha256=582c5506d19bc949194207c4bac95e2806a1527a31c81c09ec7814513dbffb05
#   Stored in directory: /root/.cache/pip/wheels/aa/5a/92/d52f6f8560ff05a2525e6030a1903412df876714241fb76802
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.1-py3-none-any.whl size=76566 sha256=0962d007df011d969928ad511640a8e4c640ed44162273b2ec1de31159f094e8
#   Stored in directory: /root/.cache/pip/wheels/95/85/b7/b4b7040e49367b6d1505d7e8fb57e3e79b22fa6ac26f72520b
#   Building wheel for unidic-lite (setup.py) ... done
#   Created wheel for unidic-lite: filename=unidic_lite-1.0.8-py3-none-any.whl size=47658837 sha256=14c9b52dec8eadae1a868c94d8a5b9f5d640d16ec9a5eda8cffd88605dfa77d0
#   Stored in directory: /root/.cache/pip/wheels/8c/dd/8f/e21fc192dcd38ae31e1185ce4e66e12df4e811e3d469866e15
#   Building wheel for gruut-ipa (setup.py) ... done
#   Created wheel for gruut-ipa: filename=gruut_ipa-0.13.0-py3-none-any.whl size=104895 sha256=11450f132eaa791ac3f587e36ab3abecf6f5820e7dc3a5d1275a6eea62c859c0
#   Stored in directory: /root/.cache/pip/wheels/bd/ef/27/f88344c08d8cca457a5316a39b099505e68a9f2a0547e0c5e7
#   Building wheel for gruut_lang_de (setup.py) ... done
#   Created wheel for gruut_lang_de: filename=gruut_lang_de-2.0.0-py3-none-any.whl size=18498199 sha256=ff309831a475fe2877a5ec9e0967a7345f288068492adca526bbb0dbba33d2ef
#   Stored in directory: /root/.cache/pip/wheels/7e/e1/60/d80ef587c3dd944644291065719d35ff92747b8e65135b2aa5
#   Building wheel for gruut_lang_en (setup.py) ... done
#   Created wheel for gruut_lang_en: filename=gruut_lang_en-2.0.0-py3-none-any.whl size=15297198 sha256=7c08941652ec27faf027a643e656654c67503861493256cfd38447e525a908fc
#   Stored in directory: /root/.cache/pip/wheels/9f/f7/60/ddc598856abe98015bfefa228160da28a0d5d0ba39b4c7ddf4
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.8-py3-none-any.whl size=55513 sha256=c3d75416bf180d0a57521c3e4a62c8d62bd5253bc8546843e639a6b8444d22e1
#   Stored in directory: /root/.cache/pip/wheels/1c/63/3a/29954bca1a27ba100ed8c27973a78cb71b43dc67aed62e80c3
#   Building wheel for gruut (setup.py) ... done
#   Created wheel for gruut: filename=gruut-2.2.3-py3-none-any.whl size=75819 sha256=30705bf2496ea5ae7a4ebee12b4bb6eb8995df4d8dc6180256b438c5418b4d9b
#   Stored in directory: /root/.cache/pip/wheels/b5/77/15/4d57c0e698b2340faa0ca0b1638ffce2683aacc4e41d5123d8
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=6f814cb5f23e74aabdb890c41f10e4d39959aa971cc9f6cddac079d883948524
#   Stored in directory: /root/.cache/pip/wheels/56/ea/58/ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
# Successfully built librosa umap-learn unidic-lite gruut-ipa gruut_lang_de gruut_lang_en pynndescent gruut docopt
# Installing collected packages: unidic-lite, python-crfsuite, mecab-python3, jamo, gruut_lang_en, gruut_lang_de, docopt, pysbd, pypinyin, numpy, num2words, networkx, llvmlite, jsonlines, inflect, gruut-ipa, cython, coqpit, anyascii, tensorboardX, numba, g2pkk, dateparser, trainer, gruut, pynndescent, librosa, umap-learn, TTS
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.0
#     Uninstalling networkx-3.0:
#       Successfully uninstalled networkx-3.0
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.39.1
#     Uninstalling llvmlite-0.39.1:
#       Successfully uninstalled llvmlite-0.39.1
#   Attempting uninstall: inflect
#     Found existing installation: inflect 2.1.0
#     Uninstalling inflect-2.1.0:
#       Successfully uninstalled inflect-2.1.0
#   Attempting uninstall: cython
#     Found existing installation: Cython 0.29.33
#     Uninstalling Cython-0.29.33:
#       Successfully uninstalled Cython-0.29.33
#   Attempting uninstall: numba
#     Found existing installation: numba 0.56.4
#     Uninstalling numba-0.56.4:
#       Successfully uninstalled numba-0.56.4
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.8.1
#     Uninstalling librosa-0.8.1:
#       Successfully uninstalled librosa-0.8.1
# Successfully installed TTS-0.11.1 anyascii-0.3.1 coqpit-0.0.17 cython-0.29.28 dateparser-1.1.7 docopt-0.6.2 g2pkk-0.1.2 gruut-2.2.3 gruut-ipa-0.13.0 gruut_lang_de-2.0.0 gruut_lang_en-2.0.0 inflect-5.6.0 jamo-0.4.1 jsonlines-1.2.0 librosa-0.8.0 llvmlite-0.38.1 mecab-python3-1.0.5 networkx-2.8.8 num2words-0.5.12 numba-0.55.1 numpy-1.21.6 pynndescent-0.5.8 pypinyin-0.48.0 pysbd-0.3.4 python-crfsuite-0.9.9 tensorboardX-2.6 trainer-0.0.20 umap-learn-0.5.1 unidic-lite-1.0.8

# %%
import gc
import torch
gc.collect()
torch.cuda.empty_cache()

# %%
# !pip install -q kaggle

# %%
from google.colab import files
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d freezerainml/ruslan
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading ruslan.zip to /content
# 100% 3.84G/3.84G [03:24<00:00, 23.1MB/s]
# 100% 3.84G/3.84G [03:24<00:00, 20.2MB/s]

# %%
# !unzip '/content/ruslan.zip'

# %%
import os
from glob import glob

from trainer import Trainer, TrainerArgs

from TTS.tts.configs.shared_configs import BaseDatasetConfig
from TTS.tts.configs.vits_config import VitsConfig
from TTS.tts.datasets import load_tts_samples
from TTS.tts.models.vits import CharactersConfig, Vits, VitsArgs, VitsAudioConfig
from TTS.tts.utils.languages import LanguageManager
from TTS.tts.utils.speakers import SpeakerManager
from TTS.tts.utils.text.tokenizer import TTSTokenizer
from TTS.utils.audio import AudioProcessor

output_path = "/content/"

dataset_config = BaseDatasetConfig(
    formatter="ruslan", meta_file_train="/content/ruslan_dataset/metadata_RUSLAN_22200.csv", 
    path='/content/ruslan_dataset/'
)

audio_config = VitsAudioConfig(
    sample_rate=16000,
    win_length=1024,
    hop_length=256,
    num_mels=80,
    mel_fmin=0,
    mel_fmax=None,
)

vitsArgs = VitsArgs(
    use_language_embedding=True,
    embedded_language_dim=4,
    use_speaker_embedding=True,
    use_sdp=False,
)
config = VitsConfig(
    model_args=vitsArgs,
    audio=audio_config,
    run_name="vits_vctk",
    use_speaker_embedding=True,
    save_all_best=True,
    batch_size=32,
    eval_batch_size=16,
    batch_group_size=0,
    num_loader_workers=4,
    num_eval_loader_workers=4,
    run_eval=True,
    test_delay_epochs=-1,
    epochs=100,
    text_cleaner="multilingual_cleaners",
    use_phonemes=False,
    phoneme_language="ru-ru",
    phoneme_cache_path=os.path.join(output_path, "phoneme_cache"),
    compute_input_seq_cache=True,
    print_step=25,
    use_language_weighted_sampler=True,
    print_eval=False,
    mixed_precision=False,
    min_audio_len=32 * 256 * 4,
    max_audio_len=160000,
    output_path=output_path,
    datasets=[dataset_config],
    characters=CharactersConfig(
        characters_class="TTS.tts.models.vits.VitsCharacters",
        pad="<PAD>",
        eos="<EOS>",
        bos="<BOS>",
        blank="<BLNK>",
        characters="!¡'(),-.:;¿?abcdefghijklmnopqrstuvwxyzµßàáâäåæçèéêëìíîïñòóôöùúûüąćęłńœśşźżƒабвгдежзийклмнопрстуфхцчшщъыьэюяёєіїґӧ «°±µ»$%&‘’‚“`”„",
        punctuations="!¡'(),-.:;¿? ",
        phonemes=None,
    ),
    test_sentences=[
        [
            "It took me quite a long time to develop a voice, and now that I have it I'm not going to be silent.",
            "mary_ann",
            None,
            "en_US",
        ],
        [
            "Il m'a fallu beaucoup de temps pour d\u00e9velopper une voix, et maintenant que je l'ai, je ne vais pas me taire.",
            "ezwa",
            None,
            "fr_FR",
        ],
        ["Ich finde, dieses Startup ist wirklich unglaublich.", "eva_k", None, "de_DE"],
        ["Я думаю, что этот стартап действительно удивительный.", "oblomov", None, "ru_RU"],
    ],
)

# init audio processor
ap = AudioProcessor.init_from_config(config)

# load training samples
train_samples, eval_samples = load_tts_samples(
    dataset_config,
    eval_split=True,
    eval_split_max_size=config.eval_split_max_size,
    eval_split_size=config.eval_split_size,
)


# INITIALIZE THE TOKENIZER
# Tokenizer is used to convert text to sequences of token IDs.
# config is updated with the default characters if not defined in the config.
tokenizer, config = TTSTokenizer.init_from_config(config)

# init model
model = Vits(config, ap, tokenizer)

# init the trainer and 🚀
trainer = Trainer(
    TrainerArgs(),
    config,
    output_path,
    model=model,
    train_samples=train_samples,
    eval_samples=eval_samples,
)
# Out:
#  > Setting up Audio Processor...
#  | > sample_rate:16000
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:0
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:None
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:None
#  | > symmetric_norm:None
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:None
#  | > pitch_fmax:None
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  | > Found 22200 files in /content/ruslan_dataset
#  > Training Environment:
#  | > Current device: 0
#  | > Num. of GPUs: 1
#  | > Num. of CPUs: 2
#  | > Num. of Torch Threads: 1
#  | > Torch seed: 54321
#  | > Torch CUDNN: True
#  | > Torch CUDNN deterministic: False
#  | > Torch CUDNN benchmark: False
#  > Start Tensorboard: tensorboard --logdir=/content/vits_vctk-March-05-2023_07+59PM-0000000
#
#  > Model has 82090365 parameters

# %%
trainer.fit()
# Out:
#  > EPOCH: 0/100
#  --> /content/vits_vctk-March-05-2023_07+59PM-0000000
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 21978
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#
#  > TRAINING (2023-03-05 19:59:55)
#  | > Preprocessing samples
#  | > Max text length: 132
#  | > Min text length: 15
#  | > Avg text length: 77.22354371498044
#  |
#  | > Max audio length: 159989.0
#  | > Min audio length: 32788.0
#  | > Avg audio length: 103850.23897875039
#  | > Num. instances discarded samples: 3060
#  | > Batch group size: 0.
# ['<BLNK>', '–', '<BLNK>', ' ', '<BLNK>', 'ч', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'ж', '<BLNK>', 'е', '<BLNK>', ' ', '<BLNK>', 'т', '<BLNK>', 'ы', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'р', '<BLNK>', 'а', '<BLNK>', 'з', '<BLNK>', 'д', '<BLNK>', 'н', '<BLNK>', 'о', '<BLNK>', 'в', '<BLNK>', 'а', '<BLNK>', 'л', '<BLNK>', ',', '<BLNK>', ' ', '<BLNK>', 'с', '<BLNK>', 'ы', '<BLNK>', 'н', '<BLNK>', 'о', '<BLNK>', 'к', '<BLNK>', '?', '<BLNK>']
#  [!] Character '–' not found in the vocabulary. Discarding it.
# ['<BLNK>', 'ж', '<BLNK>', 'и', '<BLNK>', 'т', '<BLNK>', 'ь', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'р', '<BLNK>', 'е', '<BLNK>', 'д', '<BLNK>', 'п', '<BLNK>', 'о', '<BLNK>', 'ч', '<BLNK>', 'и', '<BLNK>', 'т', '<BLNK>', 'а', '<BLNK>', 'е', '<BLNK>', 'т', '<BLNK>', ' ', '<BLNK>', 'в', '<BLNK>', ' ', '<BLNK>', 'н', '<BLNK>', 'ь', '<BLNK>', 'ю', '<BLNK>', '‑', '<BLNK>', 'й', '<BLNK>', 'о', '<BLNK>', 'р', '<BLNK>', 'к', '<BLNK>', 'е', '<BLNK>', '…', '<BLNK>']
#  [!] Character '‑' not found in the vocabulary. Discarding it.
# ['<BLNK>', 'ж', '<BLNK>', 'и', '<BLNK>', 'т', '<BLNK>', 'ь', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'р', '<BLNK>', 'е', '<BLNK>', 'д', '<BLNK>', 'п', '<BLNK>', 'о', '<BLNK>', 'ч', '<BLNK>', 'и', '<BLNK>', 'т', '<BLNK>', 'а', '<BLNK>', 'е', '<BLNK>', 'т', '<BLNK>', ' ', '<BLNK>', 'в', '<BLNK>', ' ', '<BLNK>', 'н', '<BLNK>', 'ь', '<BLNK>', 'ю', '<BLNK>', '‑', '<BLNK>', 'й', '<BLNK>', 'о', '<BLNK>', 'р', '<BLNK>', 'к', '<BLNK>', 'е', '<BLNK>', '…', '<BLNK>']
#  [!] Character '…' not found in the vocabulary. Discarding it.
# ['<BLNK>', 'р', '<BLNK>', 'е', '<BLNK>', 'ж', '<BLNK>', 'и', '<BLNK>', 'с', '<BLNK>', 'с', '<BLNK>', 'е', '<BLNK>', 'р', '<BLNK>', ' ', '<BLNK>', 'н', '<BLNK>', 'о', '<BLNK>', 'ч', '<BLNK>', 'у', '<BLNK>', 'е', '<BLNK>', 'т', '<BLNK>', ' ', '<BLNK>', 'у', '<BLNK>', ' ', '<BLNK>', 'г', '<BLNK>', 'р', '<BLNK>', 'и', '<BLNK>', 'м', '<BLNK>', 'е', '<BLNK>', 'р', '<BLNK>', 'ш', '<BLNK>', 'и', '<BLNK>', '…', '<BLNK>', '»', '<BLNK>']
#  [!] Character '…' not found in the vocabulary. Discarding it.
# /usr/local/lib/python3.8/dist-packages/torch/functional.py:632: UserWarning: stft will soon require the return_complex parameter be given for real inputs, and will further require that return_complex=True in a future PyTorch release. (Triggered internally at ../aten/src/ATen/native/SpectralOps.cpp:801.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# ['<BLNK>', '–', '<BLNK>', ' ', '<BLNK>', 'в', '<BLNK>', ' ', '<BLNK>', 'с', '<BLNK>', 'л', '<BLNK>', 'е', '<BLNK>', 'д', '<BLNK>', 'у', '<BLNK>', 'ю', '<BLNK>', 'щ', '<BLNK>', 'и', '<BLNK>', 'й', '<BLNK>', ' ', '<BLNK>', 'р', '<BLNK>', 'а', '<BLNK>', 'з', '<BLNK>', ' ', '<BLNK>', 'б', '<BLNK>', 'у', '<BLNK>', 'д', '<BLNK>', 'ь', '<BLNK>', 'т', '<BLNK>', 'е', '<BLNK>', ' ', '<BLNK>', 'а', '<BLNK>', 'к', '<BLNK>', 'т', '<BLNK>', 'и', '<BLNK>', 'в', '<BLNK>', 'н', '<BLNK>', 'е', '<BLNK>', 'е', '<BLNK>', '.', '<BLNK>']
#  [!] Character '–' not found in the vocabulary. Discarding it.
#    --> STEP: 0/592 -- GLOBAL_STEP: 0
#      | > loss_disc: 5.99036  (5.99036)
#      | > loss_disc_real_0: 1.01957  (1.01957)
#      | > loss_disc_real_1: 0.95664  (0.95664)
#      | > loss_disc_real_2: 1.02611  (1.02611)
#      | > loss_disc_real_3: 0.97346  (0.97346)
#      | > loss_disc_real_4: 0.98518  (0.98518)
#      | > loss_disc_real_5: 1.02822  (1.02822)
#      | > loss_0: 5.99036  (5.99036)
#      | > grad_norm_0: 6.73263  (6.73263)
#      | > loss_gen: 4.44501  (4.44501)
#      | > loss_kl: 148.95711  (148.95711)
#      | > loss_feat: 0.33847  (0.33847)
#      | > loss_mel: 103.48712  (103.48712)
#      | > loss_duration: 0.83971  (0.83971)
#      | > loss_1: 258.06741  (258.06741)
#      | > grad_norm_1: 1264.68542  (1264.68542)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 4.63650  (4.63651)
#      | > loader_time: 2.67350  (2.67347)
# ['<BLNK>', 'я', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'ы', '<BLNK>', 'т', '<BLNK>', 'а', '<BLNK>', 'л', '<BLNK>', 'с', '<BLNK>', 'я', '<BLNK>', ' ', '<BLNK>', 'ч', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', '‑', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'в', '<BLNK>', 'о', '<BLNK>', 'з', '<BLNK>', 'р', '<BLNK>', 'а', '<BLNK>', 'ж', '<BLNK>', 'а', '<BLNK>', 'т', '<BLNK>', 'ь', '<BLNK>', '.', '<BLNK>']
#  [!] Character '‑' not found in the vocabulary. Discarding it.
# ['<BLNK>', 'д', '<BLNK>', 'а', '<BLNK>', 'ж', '<BLNK>', 'е', '<BLNK>', ' ', '<BLNK>', '–', '<BLNK>', ' ', '<BLNK>', 'н', '<BLNK>', 'а', '<BLNK>', 'х', '<BLNK>', 'о', '<BLNK>', 'д', '<BLNK>', 'я', '<BLNK>', 'с', '<BLNK>', 'ь', '<BLNK>', ' ', '<BLNK>', 'в', '<BLNK>', ' ', '<BLNK>', 'к', '<BLNK>', 'о', '<BLNK>', 'м', '<BLNK>', 'а', '<BLNK>', 'н', '<BLNK>', 'д', '<BLNK>', 'и', '<BLNK>', 'р', '<BLNK>', 'о', '<BLNK>', 'в', '<BLNK>', 'к', '<BLNK>', 'е', '<BLNK>', '.', '<BLNK>']
#  [!] Character '–' not found in the vocabulary. Discarding it.
# ['<BLNK>', 'я', '<BLNK>', ' ', '<BLNK>', 'д', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'с', '<BLNK>', 'и', '<BLNK>', 'х', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'о', '<BLNK>', 'р', '<BLNK>', ' ', '<BLNK>', 'н', '<BLNK>', 'е', '<BLNK>', ' ', '<BLNK>', 'з', '<BLNK>', 'н', '<BLNK>', 'а', '<BLNK>', 'ю', '<BLNK>', ',', '<BLNK>', ' ', '<BLNK>', 'ч', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'э', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'т', '<BLNK>', 'а', '<BLNK>', 'к', '<BLNK>', 'о', '<BLNK>', 'е', '<BLNK>', '…', '<BLNK>']
#  [!] Character '…' not found in the vocabulary. Discarding it.
# ['<BLNK>', 'а', '<BLNK>', ' ', '<BLNK>', 'л', '<BLNK>', 'о', '<BLNK>', 'ж', '<BLNK>', 'н', '<BLNK>', 'а', '<BLNK>', 'я', '<BLNK>', ' ', '<BLNK>', 'с', '<BLNK>', 'к', '<BLNK>', 'р', '<BLNK>', 'о', '<BLNK>', 'м', '<BLNK>', 'н', '<BLNK>', 'о', '<BLNK>', 'с', '<BLNK>', 'т', '<BLNK>', 'ь', '<BLNK>', ' ', '<BLNK>', '–', '<BLNK>', ' ', '<BLNK>', 'т', '<BLNK>', 'е', '<BLNK>', 'м', '<BLNK>', ' ', '<BLNK>', 'б', '<BLNK>', 'о', '<BLNK>', 'л', '<BLNK>', 'е', '<BLNK>', 'е', '<BLNK>', '.', '<BLNK>']
#  [!] Character '–' not found in the vocabulary. Discarding it.
# ['<BLNK>', 'д', '<BLNK>', 'а', '<BLNK>', ',', '<BLNK>', ' ', '<BLNK>', 'м', '<BLNK>', 'а', '<BLNK>', 'л', '<BLNK>', 'ь', '<BLNK>', 'ч', '<BLNK>', 'и', '<BLNK>', 'к', '<BLNK>', ' ', '<BLNK>', 'к', '<BLNK>', 'а', '<BLNK>', 'к', '<BLNK>', '‑', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'с', '<BLNK>', 'и', '<BLNK>', 'м', '<BLNK>', 'в', '<BLNK>', 'о', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', 'ч', '<BLNK>', 'н', '<BLNK>', 'е', '<BLNK>', 'е', '<BLNK>', '.', '<BLNK>']
#  [!] Character '‑' not found in the vocabulary. Discarding it.
# ['<BLNK>', 'р', '<BLNK>', 'е', '<BLNK>', 'ц', '<BLNK>', 'е', '<BLNK>', 'н', '<BLNK>', 'з', '<BLNK>', 'и', '<BLNK>', 'ю', '<BLNK>', ' ', '<BLNK>', 'х', '<BLNK>', 'в', '<BLNK>', 'а', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', ' ', '<BLNK>', 'з', '<BLNK>', 'а', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'о', '<BLNK>', 'л', '<BLNK>', 'е', '<BLNK>', 'м', '<BLNK>', 'и', '<BLNK>', 'ч', '<BLNK>', 'н', '<BLNK>', 'о', '<BLNK>', 'с', '<BLNK>', 'т', '<BLNK>', 'ь', '<BLNK>', '…', '<BLNK>']
#  [!] Character '…' not found in the vocabulary. Discarding it.
#    --> STEP: 25/592 -- GLOBAL_STEP: 25
#      | > loss_disc: 2.83096  (3.14492)
#      | > loss_disc_real_0: 0.25834  (0.27448)
#      | > loss_disc_real_1: 0.23310  (0.28461)
#      | > loss_disc_real_2: 0.20494  (0.27577)
#      | > loss_disc_real_3: 0.23825  (0.29499)
#      | > loss_disc_real_4: 0.23998  (0.29856)
#      | > loss_disc_real_5: 0.20082  (0.29789)
#      | > loss_0: 2.83096  (3.14492)
#      | > grad_norm_0: 1.58508  (2.38391)
#      | > loss_gen: 1.70050  (1.68391)
#      | > loss_kl: 5.44517  (17.97519)
#      | > loss_feat: 0.95457  (0.49409)
#      | > loss_mel: 54.46906  (60.38720)
#      | > loss_duration: 0.66111  (0.68940)
#      | > loss_1: 63.23039  (81.22979)
#      | > grad_norm_1: 168.79877  (168.18526)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 2.61860  (2.65453)
#      | > loader_time: 0.00670  (0.00949)
#
#
#    --> STEP: 50/592 -- GLOBAL_STEP: 50
#      | > loss_disc: 2.33110  (2.88051)
#      | > loss_disc_real_0: 0.09546  (0.24476)
#      | > loss_disc_real_1: 0.27990  (0.26461)
#      | > loss_disc_real_2: 0.26050  (0.26354)
#      | > loss_disc_real_3: 0.31362  (0.27004)
#      | > loss_disc_real_4: 0.22767  (0.26942)
#      | > loss_disc_real_5: 0.25783  (0.26026)
#      | > loss_0: 2.33110  (2.88051)
#      | > grad_norm_0: 8.23032  (4.70476)
#      | > loss_gen: 2.15023  (1.83578)
#      | > loss_kl: 2.71537  (10.79793)
#      | > loss_feat: 2.98074  (1.26166)
#      | > loss_mel: 46.16948  (54.88676)
#      | > loss_duration: 0.61946  (0.66575)
#      | > loss_1: 54.63528  (69.44788)
#      | > grad_norm_1: 203.26564  (165.78308)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 2.72720  (2.66116)
#      | > loader_time: 0.00710  (0.01014)
# ['<BLNK>', 'в', '<BLNK>', 'я', '<BLNK>', 'л', '<BLNK>', 'ы', '<BLNK>', 'й', '<BLNK>', ' ', '<BLNK>', 'к', '<BLNK>', 'и', '<BLNK>', 'в', '<BLNK>', 'о', '<BLNK>', 'к', '<BLNK>', '.', '<BLNK>', ' ', '<BLNK>', '–', '<BLNK>', ' ', '<BLNK>', 'ч', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', '‑', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'н', '<BLNK>', 'е', '<BLNK>', ' ', '<BLNK>', 'в', '<BLNK>', 'е', '<BLNK>', 'р', '<BLNK>', 'и', '<BLNK>', 'т', '<BLNK>', 'с', '<BLNK>', 'я', '<BLNK>', '.', '<BLNK>', ' ', '<BLNK>', 'н', '<BLNK>', 'у', '<BLNK>', ' ', '<BLNK>', 'д', '<BLNK>', 'а', '<BLNK>', ' ', '<BLNK>', 'л', '<BLNK>', 'а', '<BLNK>', 'д', '<BLNK>', 'н', '<BLNK>', 'о', '<BLNK>', '.', '<BLNK>']
#  [!] Character '‑' not found in the vocabulary. Discarding it.
#    --> STEP: 75/592 -- GLOBAL_STEP: 75
#      | > loss_disc: 2.19935  (2.65611)
#      | > loss_disc_real_0: 0.05755  (0.19259)
#      | > loss_disc_real_1: 0.26920  (0.25942)
#      | > loss_disc_real_2: 0.19904  (0.25785)
#      | > loss_disc_real_3: 0.20315  (0.26026)
#      | > loss_disc_real_4: 0.15673  (0.25899)
#      | > loss_disc_real_5: 0.15420  (0.23713)
#      | > loss_0: 2.19935  (2.65611)
#      | > grad_norm_0: 10.02472  (6.37573)
#      | > loss_gen: 2.69580  (2.09634)
#      | > loss_kl: 2.31390  (8.01234)
#      | > loss_feat: 4.16959  (2.14979)
#      | > loss_mel: 49.73565  (52.38464)
#      | > loss_duration: 0.62044  (0.65159)
#      | > loss_1: 59.53538  (65.29470)
#      | > grad_norm_1: 214.13000  (161.42067)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 2.79610  (2.68060)
#      | > loader_time: 0.02080  (0.01057)
#
#
#    --> STEP: 100/592 -- GLOBAL_STEP: 100
#      | > loss_disc: 2.75678  (2.62963)
#      | > loss_disc_real_0: 0.29202  (0.18289)
#      | > loss_disc_real_1: 0.30871  (0.25789)
#      | > loss_disc_real_2: 0.21112  (0.25645)
#      | > loss_disc_real_3: 0.21042  (0.25821)
#      | > loss_disc_real_4: 0.24579  (0.25704)
#      | > loss_disc_real_5: 0.16868  (0.23849)
#      | > loss_0: 2.75678  (2.62963)
#      | > grad_norm_0: 3.52616  (6.65223)
#      | > loss_gen: 1.91846  (2.15233)
#      | > loss_kl: 1.78980  (6.48162)
#      | > loss_feat: 1.60706  (2.32984)
#      | > loss_mel: 47.18909  (51.21007)
#      | > loss_duration: 0.62653  (0.64261)
#      | > loss_1: 53.13094  (62.81646)
#      | > grad_norm_1: 240.82335  (165.76796)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 2.75560  (2.70302)
#      | > loader_time: 0.01100  (0.01072)
#
#
#    --> STEP: 125/592 -- GLOBAL_STEP: 125
#      | > loss_disc: 2.79020  (2.66560)
#      | > loss_disc_real_0: 0.26552  (0.20155)
#      | > loss_disc_real_1: 0.27813  (0.25507)
#      | > loss_disc_real_2: 0.20092  (0.25406)
#      | > loss_disc_real_3: 0.21384  (0.25428)
#      | > loss_disc_real_4: 0.19160  (0.25457)
#      | > loss_disc_real_5: 0.22078  (0.24114)
#      | > loss_0: 2.79020  (2.66560)
#      | > grad_norm_0: 3.65441  (7.36813)
#      | > loss_gen: 1.91882  (2.12165)
#      | > loss_kl: 2.45539  (5.60774)
#      | > loss_feat: 1.80924  (2.24971)
#      | > loss_mel: 41.25703  (49.75604)
#      | > loss_duration: 0.59552  (0.63372)
#      | > loss_1: 48.03600  (60.36886)
#      | > grad_norm_1: 223.52025  (178.00938)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 2.97580  (2.73263)
#      | > loader_time: 0.01510  (0.01113)
# ['<BLNK>', 'я', '<BLNK>', ' ', '<BLNK>', 'н', '<BLNK>', 'а', '<BLNK>', ' ', '<BLNK>', 'б', '<BLNK>', 'у', '<BLNK>', 'к', '<BLNK>', 'в', '<BLNK>', 'у', '<BLNK>', ' ', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', '/', '<BLNK>', 'б', '<BLNK>', 'и', '<BLNK>', 'б', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', 'о', '<BLNK>', 'г', '<BLNK>', 'р', '<BLNK>', 'а', '<BLNK>', 'ф', '<BLNK>', 'и', '<BLNK>', 'я', '<BLNK>', ' ', '<BLNK>', 'к', '<BLNK>', ' ', '<BLNK>', 'о', '<BLNK>', 'к', '<BLNK>', 'у', '<BLNK>', 'д', '<BLNK>', 'ж', '<BLNK>', 'а', '<BLNK>', 'в', '<BLNK>', 'е', '<BLNK>', '/', '<BLNK>', '.', '<BLNK>']
#  [!] Character '/' not found in the vocabulary. Discarding it.
#    --> STEP: 150/592 -- GLOBAL_STEP: 150
#      | > loss_disc: 2.35126  (2.64785)
#      | > loss_disc_real_0: 0.08617  (0.19287)
#      | > loss_disc_real_1: 0.20380  (0.25549)
#      | > loss_disc_real_2: 0.28239  (0.25259)
#      | > loss_disc_real_3: 0.31400  (0.25223)
#      | > loss_disc_real_4: 0.32506  (0.25092)
#      | > loss_disc_real_5: 0.27229  (0.23973)
#      | > loss_0: 2.35126  (2.64785)
#      | > grad_norm_0: 9.86216  (7.25380)
#      | > loss_gen: 2.59371  (2.12763)
#      | > loss_kl: 1.90677  (4.99466)
#      | > loss_feat: 3.14257  (2.27799)
#      | > loss_mel: 37.10413  (47.96114)
#      | > loss_duration: 0.60382  (0.62635)
#      | > loss_1: 45.35100  (57.98777)
#      | > grad_norm_1: 119.17648  (185.73987)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 2.92180  (2.76725)
#      | > loader_time: 0.01000  (0.01122)
#
#
#    --> STEP: 175/592 -- GLOBAL_STEP: 175
#      | > loss_disc: 2.38880  (2.62923)
#      | > loss_disc_real_0: 0.10653  (0.18567)
#      | > loss_disc_real_1: 0.17862  (0.25411)
#      | > loss_disc_real_2: 0.21827  (0.25109)
#      | > loss_disc_real_3: 0.29001  (0.25062)
#      | > loss_disc_real_4: 0.34357  (0.24600)
#      | > loss_disc_real_5: 0.27663  (0.23748)
#      | > loss_0: 2.38880  (2.62923)
#      | > grad_norm_0: 15.33381  (7.56876)
#      | > loss_gen: 2.00692  (2.12772)
#      | > loss_kl: 1.71129  (4.53580)
#      | > loss_feat: 3.03403  (2.30083)
#      | > loss_mel: 35.98129  (46.37313)
#      | > loss_duration: 0.55451  (0.61894)
#      | > loss_1: 43.28804  (55.95642)
#      | > grad_norm_1: 162.35136  (191.28218)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.05480  (2.79902)
#      | > loader_time: 0.01690  (0.01133)
#
#
#    --> STEP: 200/592 -- GLOBAL_STEP: 200
#      | > loss_disc: 2.58008  (2.62825)
#      | > loss_disc_real_0: 0.21552  (0.18828)
#      | > loss_disc_real_1: 0.19468  (0.25274)
#      | > loss_disc_real_2: 0.25327  (0.25047)
#      | > loss_disc_real_3: 0.22637  (0.24931)
#      | > loss_disc_real_4: 0.23973  (0.24068)
#      | > loss_disc_real_5: 0.23650  (0.23693)
#      | > loss_0: 2.58008  (2.62825)
#      | > grad_norm_0: 8.02732  (8.18037)
#      | > loss_gen: 1.96642  (2.12191)
#      | > loss_kl: 1.63329  (4.18007)
#      | > loss_feat: 2.06583  (2.29258)
#      | > loss_mel: 36.23226  (45.04652)
#      | > loss_duration: 0.55358  (0.61235)
#      | > loss_1: 42.45138  (54.25342)
#      | > grad_norm_1: 286.36069  (198.89090)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.12830  (2.82819)
#      | > loader_time: 0.01850  (0.01181)
#
#
#    --> STEP: 225/592 -- GLOBAL_STEP: 225
#      | > loss_disc: 2.34207  (2.61220)
#      | > loss_disc_real_0: 0.13156  (0.19161)
#      | > loss_disc_real_1: 0.32075  (0.25226)
#      | > loss_disc_real_2: 0.20415  (0.24768)
#      | > loss_disc_real_3: 0.32755  (0.24844)
#      | > loss_disc_real_4: 0.17587  (0.23394)
#      | > loss_disc_real_5: 0.25064  (0.23514)
#      | > loss_0: 2.34207  (2.61220)
#      | > grad_norm_0: 12.36931  (9.07936)
#      | > loss_gen: 1.64679  (2.12700)
#      | > loss_kl: 1.58184  (3.89547)
#      | > loss_feat: 2.82232  (2.32162)
#      | > loss_mel: 33.30642  (43.82432)
#      | > loss_duration: 0.56606  (0.60624)
#      | > loss_1: 39.92343  (52.77466)
#      | > grad_norm_1: 305.43536  (206.99777)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.10750  (2.85533)
#      | > loader_time: 0.01190  (0.01210)
# ['<BLNK>', '/', '<BLNK>', 'н', '<BLNK>', 'а', '<BLNK>', 'п', '<BLNK>', 'р', '<BLNK>', 'и', '<BLNK>', 'м', '<BLNK>', 'е', '<BLNK>', 'р', '<BLNK>', ',', '<BLNK>', ' ', '<BLNK>', 'в', '<BLNK>', 'е', '<BLNK>', 'р', '<BLNK>', 'т', '<BLNK>', 'у', '<BLNK>', 'х', '<BLNK>', 'а', '<BLNK>', 'й', '<BLNK>', ',', '<BLNK>', ' ', '<BLNK>', 'к', '<BLNK>', 'а', '<BLNK>', 'к', '<BLNK>', ' ', '<BLNK>', 'в', '<BLNK>', 'ы', '<BLNK>', ' ', '<BLNK>', 'с', '<BLNK>', 'о', '<BLNK>', 'и', '<BLNK>', 'з', '<BLNK>', 'в', '<BLNK>', 'о', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', ' ', '<BLNK>', 'д', '<BLNK>', 'р', '<BLNK>', 'у', '<BLNK>', 'ж', '<BLNK>', 'е', '<BLNK>', 'с', '<BLNK>', 'к', '<BLNK>', 'и', '<BLNK>', ' ', '<BLNK>', 'м', '<BLNK>', 'е', '<BLNK>', 'н', '<BLNK>', 'я', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'о', '<BLNK>', 'и', '<BLNK>', 'м', '<BLNK>', 'е', '<BLNK>', 'н', '<BLNK>', 'о', '<BLNK>', 'в', '<BLNK>', 'а', '<BLNK>', 'т', '<BLNK>', 'ь', '<BLNK>', '.', '<BLNK>']
#  [!] Character '/' not found in the vocabulary. Discarding it.
#    --> STEP: 250/592 -- GLOBAL_STEP: 250
#      | > loss_disc: 2.72587  (2.59563)
#      | > loss_disc_real_0: 0.17443  (0.19605)
#      | > loss_disc_real_1: 0.29597  (0.25135)
#      | > loss_disc_real_2: 0.21067  (0.24392)
#      | > loss_disc_real_3: 0.24730  (0.24645)
#      | > loss_disc_real_4: 0.27740  (0.22823)
#      | > loss_disc_real_5: 0.27022  (0.23312)
#      | > loss_0: 2.72587  (2.59563)
#      | > grad_norm_0: 8.61105  (9.79594)
#      | > loss_gen: 2.39904  (2.14861)
#      | > loss_kl: 1.49239  (3.67087)
#      | > loss_feat: 2.09123  (2.38874)
#      | > loss_mel: 33.56944  (42.83024)
#      | > loss_duration: 0.55318  (0.60090)
#      | > loss_1: 40.10527  (51.63937)
#      | > grad_norm_1: 175.32205  (212.35730)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.07630  (2.88350)
#      | > loader_time: 0.01280  (0.01243)
# ['<BLNK>', 'а', '<BLNK>', ' ', '<BLNK>', 'л', '<BLNK>', 'е', '<BLNK>', 'в', '<BLNK>', ' ', '<BLNK>', 'у', '<BLNK>', 'ф', '<BLNK>', 'л', '<BLNK>', 'я', '<BLNK>', 'н', '<BLNK>', 'д', '<BLNK>', '*', '<BLNK>', ' ', '<BLNK>', 'е', '<BLNK>', 'щ', '<BLNK>', 'е', '<BLNK>', ' ', '<BLNK>', 'б', '<BLNK>', 'о', '<BLNK>', 'л', '<BLNK>', 'ь', '<BLNK>', 'ш', '<BLNK>', 'е', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'о', '<BLNK>', 'д', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', 'в', '<BLNK>', 'а', '<BLNK>', 'е', '<BLNK>', 'т', '<BLNK>', ' ', '<BLNK>', 'ж', '<BLNK>', 'е', '<BLNK>', 'л', '<BLNK>', 'ч', '<BLNK>', 'и', '<BLNK>', ',', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'л', '<BLNK>', 'ю', '<BLNK>', 'е', '<BLNK>', 'т', '<BLNK>', ' ', '<BLNK>', 'н', '<BLNK>', 'а', '<BLNK>', ' ', '<BLNK>', 'р', '<BLNK>', 'у', '<BLNK>', 'с', '<BLNK>', 'с', '<BLNK>', 'к', '<BLNK>', 'и', '<BLNK>', 'й', '<BLNK>', ' ', '<BLNK>', 'н', '<BLNK>', 'а', '<BLNK>', 'р', '<BLNK>', 'о', '<BLNK>', 'д', '<BLNK>', '.', '<BLNK>']
#  [!] Character '*' not found in the vocabulary. Discarding it.
#    --> STEP: 275/592 -- GLOBAL_STEP: 275
#      | > loss_disc: 2.69542  (2.60528)
#      | > loss_disc_real_0: 0.06684  (0.19434)
#      | > loss_disc_real_1: 0.18190  (0.25136)
#      | > loss_disc_real_2: 0.22689  (0.24436)
#      | > loss_disc_real_3: 0.28700  (0.24539)
#      | > loss_disc_real_4: 0.25924  (0.23036)
#      | > loss_disc_real_5: 0.26144  (0.23443)
#      | > loss_0: 2.69542  (2.60528)
#      | > grad_norm_0: 18.04631  (9.71653)
#      | > loss_gen: 2.28741  (2.12745)
#      | > loss_kl: 1.77661  (3.48694)
#      | > loss_feat: 1.91113  (2.34792)
#      | > loss_mel: 32.40456  (41.97990)
#      | > loss_duration: 0.53884  (0.59666)
#      | > loss_1: 38.91854  (50.53887)
#      | > grad_norm_1: 258.89798  (216.23877)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.14930  (2.91069)
#      | > loader_time: 0.01400  (0.01268)
#
#
#    --> STEP: 300/592 -- GLOBAL_STEP: 300
#      | > loss_disc: 2.75781  (2.61672)
#      | > loss_disc_real_0: 0.19331  (0.19506)
#      | > loss_disc_real_1: 0.25238  (0.25123)
#      | > loss_disc_real_2: 0.24940  (0.24470)
#      | > loss_disc_real_3: 0.26603  (0.24416)
#      | > loss_disc_real_4: 0.19802  (0.23142)
#      | > loss_disc_real_5: 0.24496  (0.23530)
#      | > loss_0: 2.75781  (2.61672)
#      | > grad_norm_0: 6.48499  (9.76504)
#      | > loss_gen: 1.93611  (2.10969)
#      | > loss_kl: 1.59905  (3.33463)
#      | > loss_feat: 1.62524  (2.30220)
#      | > loss_mel: 32.02933  (41.24370)
#      | > loss_duration: 0.55651  (0.59313)
#      | > loss_1: 37.74623  (49.58335)
#      | > grad_norm_1: 256.57983  (220.78113)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.14350  (2.93449)
#      | > loader_time: 0.01270  (0.01312)
#
#
#    --> STEP: 325/592 -- GLOBAL_STEP: 325
#      | > loss_disc: 2.66751  (2.62531)
#      | > loss_disc_real_0: 0.16164  (0.19784)
#      | > loss_disc_real_1: 0.25567  (0.25141)
#      | > loss_disc_real_2: 0.19758  (0.24432)
#      | > loss_disc_real_3: 0.14571  (0.24319)
#      | > loss_disc_real_4: 0.25381  (0.23115)
#      | > loss_disc_real_5: 0.26061  (0.23566)
#      | > loss_0: 2.66751  (2.62531)
#      | > grad_norm_0: 11.74379  (9.91489)
#      | > loss_gen: 1.85328  (2.09401)
#      | > loss_kl: 1.56169  (3.20259)
#      | > loss_feat: 2.02459  (2.26151)
#      | > loss_mel: 32.71108  (40.54845)
#      | > loss_duration: 0.54424  (0.58999)
#      | > loss_1: 38.69489  (48.69655)
#      | > grad_norm_1: 301.68155  (223.28748)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.20280  (2.95872)
#      | > loader_time: 0.01590  (0.01341)
# ['<BLNK>', 'б', '<BLNK>', 'р', '<BLNK>', 'а', '<BLNK>', 'т', '<BLNK>', ' ', '<BLNK>', 'р', '<BLNK>', 'а', '<BLNK>', 'з', '<BLNK>', 'ъ', '<BLNK>', 'е', '<BLNK>', 'з', '<BLNK>', 'ж', '<BLNK>', 'а', '<BLNK>', 'л', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'о', '<BLNK>', 'т', '<BLNK>', 'д', '<BLNK>', 'а', '<BLNK>', 'л', '<BLNK>', 'е', '<BLNK>', 'н', '<BLNK>', 'н', '<BLNK>', 'ы', '<BLNK>', 'м', '<BLNK>', ' ', '<BLNK>', 'л', '<BLNK>', 'а', '<BLNK>', 'г', '<BLNK>', 'е', '<BLNK>', 'р', '<BLNK>', 'н', '<BLNK>', 'ы', '<BLNK>', 'м', '<BLNK>', ' ', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', 'ч', '<BLNK>', 'к', '<BLNK>', 'а', '<BLNK>', 'м', '<BLNK>', '.', '<BLNK>', ' ', '<BLNK>', 'е', '<BLNK>', 'м', '<BLNK>', 'у', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'р', '<BLNK>', 'е', '<BLNK>', 'д', '<BLNK>', 'о', '<BLNK>', 'с', '<BLNK>', 'т', '<BLNK>', 'а', '<BLNK>', 'в', '<BLNK>', 'и', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', ' ', '<BLNK>', 'к', '<BLNK>', 'а', '<BLNK>', 'з', '<BLNK>', 'е', '<BLNK>', 'н', '<BLNK>', 'н', '<BLNK>', 'у', '<BLNK>', 'ю', '<BLNK>', ' ', '<BLNK>', 'м', '<BLNK>', 'а', '<BLNK>', 'ш', '<BLNK>', 'и', '<BLNK>', 'н', '<BLNK>', 'у', '<BLNK>', ' ', '<BLNK>', '«', '<BLNK>', 'г', '<BLNK>', 'а', '<BLNK>', 'з', '<BLNK>', '‑', '<BLNK>', '6', '<BLNK>', '1', '<BLNK>', '»', '<BLNK>', '.', '<BLNK>']
#  [!] Character '6' not found in the vocabulary. Discarding it.
# ['<BLNK>', 'б', '<BLNK>', 'р', '<BLNK>', 'а', '<BLNK>', 'т', '<BLNK>', ' ', '<BLNK>', 'р', '<BLNK>', 'а', '<BLNK>', 'з', '<BLNK>', 'ъ', '<BLNK>', 'е', '<BLNK>', 'з', '<BLNK>', 'ж', '<BLNK>', 'а', '<BLNK>', 'л', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'о', '<BLNK>', 'т', '<BLNK>', 'д', '<BLNK>', 'а', '<BLNK>', 'л', '<BLNK>', 'е', '<BLNK>', 'н', '<BLNK>', 'н', '<BLNK>', 'ы', '<BLNK>', 'м', '<BLNK>', ' ', '<BLNK>', 'л', '<BLNK>', 'а', '<BLNK>', 'г', '<BLNK>', 'е', '<BLNK>', 'р', '<BLNK>', 'н', '<BLNK>', 'ы', '<BLNK>', 'м', '<BLNK>', ' ', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', 'ч', '<BLNK>', 'к', '<BLNK>', 'а', '<BLNK>', 'м', '<BLNK>', '.', '<BLNK>', ' ', '<BLNK>', 'е', '<BLNK>', 'м', '<BLNK>', 'у', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'р', '<BLNK>', 'е', '<BLNK>', 'д', '<BLNK>', 'о', '<BLNK>', 'с', '<BLNK>', 'т', '<BLNK>', 'а', '<BLNK>', 'в', '<BLNK>', 'и', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', ' ', '<BLNK>', 'к', '<BLNK>', 'а', '<BLNK>', 'з', '<BLNK>', 'е', '<BLNK>', 'н', '<BLNK>', 'н', '<BLNK>', 'у', '<BLNK>', 'ю', '<BLNK>', ' ', '<BLNK>', 'м', '<BLNK>', 'а', '<BLNK>', 'ш', '<BLNK>', 'и', '<BLNK>', 'н', '<BLNK>', 'у', '<BLNK>', ' ', '<BLNK>', '«', '<BLNK>', 'г', '<BLNK>', 'а', '<BLNK>', 'з', '<BLNK>', '‑', '<BLNK>', '6', '<BLNK>', '1', '<BLNK>', '»', '<BLNK>', '.', '<BLNK>']
#  [!] Character '1' not found in the vocabulary. Discarding it.
#    --> STEP: 350/592 -- GLOBAL_STEP: 350
#      | > loss_disc: 2.67921  (2.63747)
#      | > loss_disc_real_0: 0.12431  (0.20049)
#      | > loss_disc_real_1: 0.24039  (0.25130)
#      | > loss_disc_real_2: 0.24483  (0.24443)
#      | > loss_disc_real_3: 0.26139  (0.24390)
#      | > loss_disc_real_4: 0.19436  (0.23199)
#      | > loss_disc_real_5: 0.20098  (0.23563)
#      | > loss_0: 2.67921  (2.63747)
#      | > grad_norm_0: 9.83336  (10.05711)
#      | > loss_gen: 1.85034  (2.07810)
#      | > loss_kl: 1.52657  (3.08848)
#      | > loss_feat: 1.85405  (2.21443)
#      | > loss_mel: 30.52396  (39.87231)
#      | > loss_duration: 0.56807  (0.58774)
#      | > loss_1: 36.32299  (47.84106)
#      | > grad_norm_1: 435.56174  (227.63310)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.24390  (2.98038)
#      | > loader_time: 0.01430  (0.01375)
#
#
#    --> STEP: 375/592 -- GLOBAL_STEP: 375
#      | > loss_disc: 2.76193  (2.65065)
#      | > loss_disc_real_0: 0.17057  (0.20284)
#      | > loss_disc_real_1: 0.28241  (0.25111)
#      | > loss_disc_real_2: 0.28357  (0.24493)
#      | > loss_disc_real_3: 0.24099  (0.24400)
#      | > loss_disc_real_4: 0.20145  (0.23260)
#      | > loss_disc_real_5: 0.23181  (0.23547)
#      | > loss_0: 2.76193  (2.65065)
#      | > grad_norm_0: 6.71972  (9.91770)
#      | > loss_gen: 1.82765  (2.05820)
#      | > loss_kl: 1.57130  (2.98797)
#      | > loss_feat: 1.48392  (2.15799)
#      | > loss_mel: 31.06170  (39.28105)
#      | > loss_duration: 0.56817  (0.58550)
#      | > loss_1: 36.51273  (47.07070)
#      | > grad_norm_1: 247.32910  (231.06680)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.26820  (3.00164)
#      | > loader_time: 0.01380  (0.01395)
#
#
#    --> STEP: 400/592 -- GLOBAL_STEP: 400
#      | > loss_disc: 2.75058  (2.66141)
#      | > loss_disc_real_0: 0.26243  (0.20428)
#      | > loss_disc_real_1: 0.27451  (0.25085)
#      | > loss_disc_real_2: 0.26274  (0.24491)
#      | > loss_disc_real_3: 0.20098  (0.24363)
#      | > loss_disc_real_4: 0.28682  (0.23324)
#      | > loss_disc_real_5: 0.27200  (0.23608)
#      | > loss_0: 2.75058  (2.66141)
#      | > grad_norm_0: 7.29004  (9.67911)
#      | > loss_gen: 1.62753  (2.03901)
#      | > loss_kl: 1.57508  (2.90398)
#      | > loss_feat: 1.37406  (2.10595)
#      | > loss_mel: 28.93336  (38.71927)
#      | > loss_duration: 0.56483  (0.58376)
#      | > loss_1: 34.07486  (46.35197)
#      | > grad_norm_1: 241.23296  (232.94933)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.43380  (3.02043)
#      | > loader_time: 0.03150  (0.01427)
# ['<BLNK>', 'н', '<BLNK>', 'а', '<BLNK>', ' ', '<BLNK>', 'ф', '<BLNK>', 'и', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', 'п', '<BLNK>', 'п', '<BLNK>', 'и', '<BLNK>', 'н', '<BLNK>', 'а', '<BLNK>', 'х', '<BLNK>', ' ', '<BLNK>', 'к', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', '‑', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'з', '<BLNK>', 'а', '<BLNK>', 'с', '<BLNK>', 'т', '<BLNK>', 'р', '<BLNK>', 'е', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', 'л', '<BLNK>', ' ', '<BLNK>', 'р', '<BLNK>', 'у', '<BLNK>', 'к', '<BLNK>', 'о', '<BLNK>', 'в', '<BLNK>', 'о', '<BLNK>', 'д', '<BLNK>', 'и', '<BLNK>', 'т', '<BLNK>', 'е', '<BLNK>', 'л', '<BLNK>', 'я', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'а', '<BLNK>', 'р', '<BLNK>', 'т', '<BLNK>', 'и', '<BLNK>', 'й', '<BLNK>', 'н', '<BLNK>', 'о', '<BLNK>', 'й', '<BLNK>', ' ', '<BLNK>', 'о', '<BLNK>', 'п', '<BLNK>', 'п', '<BLNK>', 'о', '<BLNK>', 'з', '<BLNK>', 'и', '<BLNK>', 'ц', '<BLNK>', 'и', '<BLNK>', 'и', '<BLNK>', '.', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'о', '<BLNK>', 'д', '<BLNK>', ' ', '<BLNK>', 'м', '<BLNK>', 'е', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', 'п', '<BLNK>', 'о', '<BLNK>', 'л', '<BLNK>', 'е', '<BLNK>', 'м', '<BLNK>', ' ', '<BLNK>', 'р', '<BLNK>', 'а', '<BLNK>', 'з', '<BLNK>', 'б', '<BLNK>', 'и', '<BLNK>', 'л', '<BLNK>', 'с', '<BLNK>', 'я', '<BLNK>', ' ', '<BLNK>', '«', '<BLNK>', 'т', '<BLNK>', 'у', '<BLNK>', '‑', '<BLNK>', '1', '<BLNK>', '2', '<BLNK>', '9', '<BLNK>', '»', '<BLNK>', '.', '<BLNK>']
#  [!] Character '1' not found in the vocabulary. Discarding it.
# ['<BLNK>', 'н', '<BLNK>', 'а', '<BLNK>', ' ', '<BLNK>', 'ф', '<BLNK>', 'и', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', 'п', '<BLNK>', 'п', '<BLNK>', 'и', '<BLNK>', 'н', '<BLNK>', 'а', '<BLNK>', 'х', '<BLNK>', ' ', '<BLNK>', 'к', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', '‑', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'з', '<BLNK>', 'а', '<BLNK>', 'с', '<BLNK>', 'т', '<BLNK>', 'р', '<BLNK>', 'е', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', 'л', '<BLNK>', ' ', '<BLNK>', 'р', '<BLNK>', 'у', '<BLNK>', 'к', '<BLNK>', 'о', '<BLNK>', 'в', '<BLNK>', 'о', '<BLNK>', 'д', '<BLNK>', 'и', '<BLNK>', 'т', '<BLNK>', 'е', '<BLNK>', 'л', '<BLNK>', 'я', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'а', '<BLNK>', 'р', '<BLNK>', 'т', '<BLNK>', 'и', '<BLNK>', 'й', '<BLNK>', 'н', '<BLNK>', 'о', '<BLNK>', 'й', '<BLNK>', ' ', '<BLNK>', 'о', '<BLNK>', 'п', '<BLNK>', 'п', '<BLNK>', 'о', '<BLNK>', 'з', '<BLNK>', 'и', '<BLNK>', 'ц', '<BLNK>', 'и', '<BLNK>', 'и', '<BLNK>', '.', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'о', '<BLNK>', 'д', '<BLNK>', ' ', '<BLNK>', 'м', '<BLNK>', 'е', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', 'п', '<BLNK>', 'о', '<BLNK>', 'л', '<BLNK>', 'е', '<BLNK>', 'м', '<BLNK>', ' ', '<BLNK>', 'р', '<BLNK>', 'а', '<BLNK>', 'з', '<BLNK>', 'б', '<BLNK>', 'и', '<BLNK>', 'л', '<BLNK>', 'с', '<BLNK>', 'я', '<BLNK>', ' ', '<BLNK>', '«', '<BLNK>', 'т', '<BLNK>', 'у', '<BLNK>', '‑', '<BLNK>', '1', '<BLNK>', '2', '<BLNK>', '9', '<BLNK>', '»', '<BLNK>', '.', '<BLNK>']
#  [!] Character '2' not found in the vocabulary. Discarding it.
# ['<BLNK>', 'н', '<BLNK>', 'а', '<BLNK>', ' ', '<BLNK>', 'ф', '<BLNK>', 'и', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', 'п', '<BLNK>', 'п', '<BLNK>', 'и', '<BLNK>', 'н', '<BLNK>', 'а', '<BLNK>', 'х', '<BLNK>', ' ', '<BLNK>', 'к', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', '‑', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'з', '<BLNK>', 'а', '<BLNK>', 'с', '<BLNK>', 'т', '<BLNK>', 'р', '<BLNK>', 'е', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', 'л', '<BLNK>', ' ', '<BLNK>', 'р', '<BLNK>', 'у', '<BLNK>', 'к', '<BLNK>', 'о', '<BLNK>', 'в', '<BLNK>', 'о', '<BLNK>', 'д', '<BLNK>', 'и', '<BLNK>', 'т', '<BLNK>', 'е', '<BLNK>', 'л', '<BLNK>', 'я', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'а', '<BLNK>', 'р', '<BLNK>', 'т', '<BLNK>', 'и', '<BLNK>', 'й', '<BLNK>', 'н', '<BLNK>', 'о', '<BLNK>', 'й', '<BLNK>', ' ', '<BLNK>', 'о', '<BLNK>', 'п', '<BLNK>', 'п', '<BLNK>', 'о', '<BLNK>', 'з', '<BLNK>', 'и', '<BLNK>', 'ц', '<BLNK>', 'и', '<BLNK>', 'и', '<BLNK>', '.', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'о', '<BLNK>', 'д', '<BLNK>', ' ', '<BLNK>', 'м', '<BLNK>', 'е', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', 'п', '<BLNK>', 'о', '<BLNK>', 'л', '<BLNK>', 'е', '<BLNK>', 'м', '<BLNK>', ' ', '<BLNK>', 'р', '<BLNK>', 'а', '<BLNK>', 'з', '<BLNK>', 'б', '<BLNK>', 'и', '<BLNK>', 'л', '<BLNK>', 'с', '<BLNK>', 'я', '<BLNK>', ' ', '<BLNK>', '«', '<BLNK>', 'т', '<BLNK>', 'у', '<BLNK>', '‑', '<BLNK>', '1', '<BLNK>', '2', '<BLNK>', '9', '<BLNK>', '»', '<BLNK>', '.', '<BLNK>']
#  [!] Character '9' not found in the vocabulary. Discarding it.
# ['<BLNK>', 'п', '<BLNK>', 'о', '<BLNK>', '‑', '<BLNK>', 'р', '<BLNK>', 'у', '<BLNK>', 'с', '<BLNK>', 'с', '<BLNK>', 'к', '<BLNK>', 'и', '<BLNK>', ' ', '<BLNK>', 'м', '<BLNK>', 'о', '<BLNK>', 'ж', '<BLNK>', 'н', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'с', '<BLNK>', 'к', '<BLNK>', 'а', '<BLNK>', 'з', '<BLNK>', 'а', '<BLNK>', 'т', '<BLNK>', 'ь', '<BLNK>', ' ', '<BLNK>', '–', '<BLNK>', ' ', '<BLNK>', 'ё', '<BLNK>', 'б', '<BLNK>', 'н', '<BLNK>', 'у', '<BLNK>', 'л', '<BLNK>', 'с', '<BLNK>', 'я', '<BLNK>', ',', '<BLNK>', ' ', '<BLNK>', 'е', '<BLNK>', 'б', '<BLNK>', 'а', '<BLNK>', 'н', '<BLNK>', 'у', '<BLNK>', '́', '<BLNK>', 'л', '<BLNK>', 'с', '<BLNK>', 'я', '<BLNK>', ' ', '<BLNK>', 'и', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', ' ', '<BLNK>', 'н', '<BLNK>', 'а', '<BLNK>', 'е', '<BLNK>', 'б', '<BLNK>', 'н', '<BLNK>', 'у', '<BLNK>', '́', '<BLNK>', 'л', '<BLNK>', 'с', '<BLNK>', 'я', '<BLNK>', '.', '<BLNK>']
#  [!] Character '́' not found in the vocabulary. Discarding it.
#    --> STEP: 425/592 -- GLOBAL_STEP: 425
#      | > loss_disc: 3.24233  (2.69372)
#      | > loss_disc_real_0: 0.23975  (0.20534)
#      | > loss_disc_real_1: 0.25260  (0.25123)
#      | > loss_disc_real_2: 0.30993  (0.24944)
#      | > loss_disc_real_3: 0.15779  (0.24451)
#      | > loss_disc_real_4: 0.58766  (0.24456)
#      | > loss_disc_real_5: 0.78595  (0.24611)
#      | > loss_0: 3.24233  (2.69372)
#      | > grad_norm_0: 11.55890  (10.33282)
#      | > loss_gen: 2.21889  (2.06226)
#      | > loss_kl: 1.71610  (2.83458)
#      | > loss_feat: 1.64288  (2.09649)
#      | > loss_mel: 29.48994  (38.22359)
#      | > loss_duration: 0.56310  (0.58244)
#      | > loss_1: 35.63091  (45.79936)
#      | > grad_norm_1: 254.42690  (235.23772)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.36960  (3.03808)
#      | > loader_time: 0.01640  (0.01455)
#
#
#    --> STEP: 450/592 -- GLOBAL_STEP: 450
#      | > loss_disc: 2.73684  (2.70397)
#      | > loss_disc_real_0: 0.25209  (0.20669)
#      | > loss_disc_real_1: 0.25864  (0.25122)
#      | > loss_disc_real_2: 0.23705  (0.24920)
#      | > loss_disc_real_3: 0.25368  (0.24434)
#      | > loss_disc_real_4: 0.21903  (0.24374)
#      | > loss_disc_real_5: 0.24679  (0.24742)
#      | > loss_0: 2.73684  (2.70397)
#      | > grad_norm_0: 3.09525  (10.17091)
#      | > loss_gen: 1.87039  (2.04650)
#      | > loss_kl: 1.74419  (2.77260)
#      | > loss_feat: 1.19864  (2.05439)
#      | > loss_mel: 29.02211  (37.77028)
#      | > loss_duration: 0.57721  (0.58152)
#      | > loss_1: 34.41253  (45.22529)
#      | > grad_norm_1: 177.18718  (235.80806)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.27250  (3.05654)
#      | > loader_time: 0.01640  (0.01483)
#
#
#    --> STEP: 475/592 -- GLOBAL_STEP: 475
#      | > loss_disc: 2.75835  (2.71343)
#      | > loss_disc_real_0: 0.29087  (0.20790)
#      | > loss_disc_real_1: 0.29345  (0.25110)
#      | > loss_disc_real_2: 0.25299  (0.24939)
#      | > loss_disc_real_3: 0.30737  (0.24603)
#      | > loss_disc_real_4: 0.23313  (0.24366)
#      | > loss_disc_real_5: 0.24851  (0.24734)
#      | > loss_0: 2.75835  (2.71343)
#      | > grad_norm_0: 6.35603  (10.00064)
#      | > loss_gen: 1.65941  (2.03199)
#      | > loss_kl: 1.56739  (2.71591)
#      | > loss_feat: 1.13823  (2.01185)
#      | > loss_mel: 28.57930  (37.32329)
#      | > loss_duration: 0.57410  (0.58088)
#      | > loss_1: 33.51842  (44.66391)
#      | > grad_norm_1: 282.93787  (237.59776)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.34320  (3.07291)
#      | > loader_time: 0.01520  (0.01504)
#
#
#    --> STEP: 500/592 -- GLOBAL_STEP: 500
#      | > loss_disc: 2.83386  (2.71944)
#      | > loss_disc_real_0: 0.19141  (0.20831)
#      | > loss_disc_real_1: 0.27367  (0.25085)
#      | > loss_disc_real_2: 0.21876  (0.24878)
#      | > loss_disc_real_3: 0.26858  (0.24547)
#      | > loss_disc_real_4: 0.21954  (0.24367)
#      | > loss_disc_real_5: 0.22060  (0.24688)
#      | > loss_0: 2.83386  (2.71944)
#      | > grad_norm_0: 3.21117  (9.73096)
#      | > loss_gen: 1.84346  (2.01517)
#      | > loss_kl: 1.69277  (2.66532)
#      | > loss_feat: 1.18202  (1.96586)
#      | > loss_mel: 28.41758  (36.89067)
#      | > loss_duration: 0.58708  (0.58069)
#      | > loss_1: 33.72292  (44.11772)
#      | > grad_norm_1: 306.94141  (239.61461)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.44540  (3.08980)
#      | > loader_time: 0.01610  (0.01517)
# ['<BLNK>', 'н', '<BLNK>', 'е', '<BLNK>', ' ', '<BLNK>', 'х', '<BLNK>', 'о', '<BLNK>', 'ч', '<BLNK>', 'у', '<BLNK>', ' ', '<BLNK>', 'д', '<BLNK>', 'е', '<BLNK>', 'м', '<BLNK>', 'о', '<BLNK>', 'н', '<BLNK>', 'с', '<BLNK>', 'т', '<BLNK>', 'р', '<BLNK>', 'и', '<BLNK>', 'р', '<BLNK>', 'о', '<BLNK>', 'в', '<BLNK>', 'а', '<BLNK>', 'т', '<BLNK>', 'ь', '<BLNK>', ' ', '<BLNK>', 'с', '<BLNK>', 'в', '<BLNK>', 'о', '<BLNK>', 'е', '<BLNK>', 'г', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'р', '<BLNK>', 'е', '<BLNK>', 'в', '<BLNK>', 'о', '<BLNK>', 'с', '<BLNK>', 'х', '<BLNK>', 'о', '<BLNK>', 'д', '<BLNK>', 'с', '<BLNK>', 'т', '<BLNK>', 'в', '<BLNK>', 'а', '<BLNK>', '…', '<BLNK>', ' ', '<BLNK>', 'м', '<BLNK>', 'ы', '<BLNK>', ' ', '<BLNK>', 'б', '<BLNK>', 'у', '<BLNK>', 'д', '<BLNK>', 'е', '<BLNK>', 'м', '<BLNK>', ' ', '<BLNK>', 'в', '<BLNK>', 'ы', '<BLNK>', 'ш', '<BLNK>', 'е', '<BLNK>', ' ', '<BLNK>', 'э', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', 'г', '<BLNK>', 'о', '<BLNK>', '.', '<BLNK>', ' ', '<BLNK>', 'о', '<BLNK>', 'т', '<BLNK>', 'в', '<BLNK>', 'е', '<BLNK>', 'т', '<BLNK>', 'и', '<BLNK>', 'м', '<BLNK>', ' ', '<BLNK>', 'е', '<BLNK>', 'й', '<BLNK>', ' ', '<BLNK>', 'д', '<BLNK>', 'о', '<BLNK>', 'б', '<BLNK>', 'р', '<BLNK>', 'о', '<BLNK>', 'м', '<BLNK>', ' ', '<BLNK>', 'н', '<BLNK>', 'а', '<BLNK>', ' ', '<BLNK>', 'з', '<BLNK>', 'л', '<BLNK>', 'о', '<BLNK>', '…', '<BLNK>', ' ', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'ч', '<BLNK>', 'е', '<BLNK>', 'м', '<BLNK>', ' ', '<BLNK>', 'т', '<BLNK>', 'ы', '<BLNK>', ' ', '<BLNK>', 'д', '<BLNK>', 'у', '<BLNK>', 'м', '<BLNK>', 'а', '<BLNK>', 'е', '<BLNK>', 'ш', '<BLNK>', 'ь', '<BLNK>', '/', '<BLNK>', '.', '<BLNK>', '.', '<BLNK>']
#  [!] Character '/' not found in the vocabulary. Discarding it.
#    --> STEP: 525/592 -- GLOBAL_STEP: 525
#      | > loss_disc: 2.81185  (2.72427)
#      | > loss_disc_real_0: 0.26008  (0.20848)
#      | > loss_disc_real_1: 0.21447  (0.25069)
#      | > loss_disc_real_2: 0.18632  (0.24835)
#      | > loss_disc_real_3: 0.31218  (0.24550)
#      | > loss_disc_real_4: 0.22553  (0.24374)
#      | > loss_disc_real_5: 0.25525  (0.24693)
#      | > loss_0: 2.81185  (2.72427)
#      | > grad_norm_0: 4.54610  (9.47575)
#      | > loss_gen: 1.58986  (2.00099)
#      | > loss_kl: 1.68038  (2.61987)
#      | > loss_feat: 1.10308  (1.92658)
#      | > loss_mel: 27.24844  (36.46859)
#      | > loss_duration: 0.59656  (0.58097)
#      | > loss_1: 32.21833  (43.59699)
#      | > grad_norm_1: 236.32036  (241.44025)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.41070  (3.10641)
#      | > loader_time: 0.01620  (0.01538)
#
#
#    --> STEP: 550/592 -- GLOBAL_STEP: 550
#      | > loss_disc: 2.89430  (2.73049)
#      | > loss_disc_real_0: 0.17453  (0.20924)
#      | > loss_disc_real_1: 0.35574  (0.25073)
#      | > loss_disc_real_2: 0.21352  (0.24852)
#      | > loss_disc_real_3: 0.17790  (0.24543)
#      | > loss_disc_real_4: 0.16629  (0.24344)
#      | > loss_disc_real_5: 0.29734  (0.24688)
#      | > loss_0: 2.89430  (2.73049)
#      | > grad_norm_0: 11.15653  (9.38932)
#      | > loss_gen: 1.64090  (1.98960)
#      | > loss_kl: 1.64403  (2.57769)
#      | > loss_feat: 1.25411  (1.89197)
#      | > loss_mel: 28.79346  (36.08399)
#      | > loss_duration: 0.59503  (0.58170)
#      | > loss_1: 33.92753  (43.12496)
#      | > grad_norm_1: 248.73976  (242.20586)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.58970  (3.12328)
#      | > loader_time: 0.03440  (0.01563)
# ['<BLNK>', 'в', '<BLNK>', ' ', '<BLNK>', 'с', '<BLNK>', 'у', '<BLNK>', 'м', '<BLNK>', 'о', '<BLNK>', 'ч', '<BLNK>', 'к', '<BLNK>', 'е', '<BLNK>', ' ', '<BLNK>', 'е', '<BLNK>', 'е', '<BLNK>', ' ', '<BLNK>', 'л', '<BLNK>', 'е', '<BLNK>', 'ж', '<BLNK>', 'а', '<BLNK>', 'л', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'н', '<BLNK>', 'е', '<BLNK>', 'ч', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', ',', '<BLNK>', ' ', '<BLNK>', 'р', '<BLNK>', 'а', '<BLNK>', 'з', '<BLNK>', 'м', '<BLNK>', 'е', '<BLNK>', 'р', '<BLNK>', 'о', '<BLNK>', 'м', '<BLNK>', ' ', '<BLNK>', 'ч', '<BLNK>', 'у', '<BLNK>', 'т', '<BLNK>', 'ь', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'о', '<BLNK>', 'б', '<BLNK>', 'о', '<BLNK>', 'л', '<BLNK>', 'е', '<BLNK>', 'е', '<BLNK>', ' ', '<BLNK>', 'м', '<BLNK>', 'и', '<BLNK>', 'н', '<BLNK>', 'и', '<BLNK>', 'а', '<BLNK>', 'т', '<BLNK>', 'ю', '<BLNK>', 'р', '<BLNK>', 'н', '<BLNK>', 'о', '<BLNK>', 'г', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'д', '<BLNK>', 'а', '<BLNK>', 'м', '<BLNK>', 'с', '<BLNK>', 'к', '<BLNK>', 'о', '<BLNK>', 'г', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'б', '<BLNK>', 'р', '<BLNK>', 'а', '<BLNK>', 'у', '<BLNK>', 'н', '<BLNK>', 'и', '<BLNK>', 'н', '<BLNK>', 'г', '<BLNK>', 'а', '<BLNK>', ' ', '<BLNK>', '«', '<BLNK>', 'э', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', 'т', '<BLNK>', 'а', '<BLNK>', '‑', '<BLNK>', '1', '<BLNK>', '6', '<BLNK>', '»', '<BLNK>', '.', '<BLNK>']
#  [!] Character '6' not found in the vocabulary. Discarding it.
#    --> STEP: 575/592 -- GLOBAL_STEP: 575
#      | > loss_disc: 2.79625  (2.73517)
#      | > loss_disc_real_0: 0.20631  (0.21019)
#      | > loss_disc_real_1: 0.22493  (0.25035)
#      | > loss_disc_real_2: 0.24030  (0.24810)
#      | > loss_disc_real_3: 0.15506  (0.24499)
#      | > loss_disc_real_4: 0.22272  (0.24319)
#      | > loss_disc_real_5: 0.22666  (0.24667)
#      | > loss_0: 2.79625  (2.73517)
#      | > grad_norm_0: 3.84570  (9.20816)
#      | > loss_gen: 1.63136  (1.97673)
#      | > loss_kl: 1.71941  (2.53713)
#      | > loss_feat: 1.13384  (1.85776)
#      | > loss_mel: 27.24869  (35.68986)
#      | > loss_duration: 0.62199  (0.58300)
#      | > loss_1: 32.35528  (42.64449)
#      | > grad_norm_1: 419.15323  (242.91690)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.41370  (3.13995)
#      | > loader_time: 0.01690  (0.01588)
#
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 222
#  | > Preprocessing samples
#  | > Max text length: 118
#  | > Min text length: 18
#  | > Avg text length: 81.47619047619048
#  |
#  | > Max audio length: 159093.0
#  | > Min audio length: 33172.0
#  | > Avg audio length: 109915.1164021164
#  | > Num. instances discarded samples: 33
#  | > Batch group size: 0.
# ['<BLNK>', 'в', '<BLNK>', ' ', '<BLNK>', 'э', '<BLNK>', 'м', '<BLNK>', 'и', '<BLNK>', 'г', '<BLNK>', 'р', '<BLNK>', 'а', '<BLNK>', 'ц', '<BLNK>', 'и', '<BLNK>', 'и', '<BLNK>', ' ', '<BLNK>', 'б', '<BLNK>', 'ы', '<BLNK>', 'л', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'ч', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', '‑', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'н', '<BLNK>', 'е', '<BLNK>', 'р', '<BLNK>', 'е', '<BLNK>', 'а', '<BLNK>', 'л', '<BLNK>', 'ь', '<BLNK>', 'н', '<BLNK>', 'о', '<BLNK>', 'е', '<BLNK>', '.', '<BLNK>', ' ', '<BLNK>', 'ч', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', '‑', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', ',', '<BLNK>', ' ', '<BLNK>', 'н', '<BLNK>', 'а', '<BLNK>', 'п', '<BLNK>', 'о', '<BLNK>', 'м', '<BLNK>', 'и', '<BLNK>', 'н', '<BLNK>', 'а', '<BLNK>', 'ю', '<BLNK>', 'щ', '<BLNK>', 'е', '<BLNK>', 'е', '<BLNK>', ' ', '<BLNK>', 'и', '<BLNK>', 'д', '<BLNK>', 'е', '<BLNK>', 'ю', '<BLNK>', ' ', '<BLNK>', 'з', '<BLNK>', 'а', '<BLNK>', 'г', '<BLNK>', 'р', '<BLNK>', 'о', '<BLNK>', 'б', '<BLNK>', 'н', '<BLNK>', 'о', '<BLNK>', 'й', '<BLNK>', ' ', '<BLNK>', 'ж', '<BLNK>', 'и', '<BLNK>', 'з', '<BLNK>', 'н', '<BLNK>', 'и', '<BLNK>', '.', '<BLNK>']
#  [!] Character '‑' not found in the vocabulary. Discarding it.
# ['<BLNK>', 'к', '<BLNK>', 'р', '<BLNK>', 'о', '<BLNK>', 'м', '<BLNK>', 'е', '<BLNK>', ' ', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', 'г', '<BLNK>', 'о', '<BLNK>', ',', '<BLNK>', ' ', '<BLNK>', 'д', '<BLNK>', 'о', '<BLNK>', 'н', '<BLNK>', 'о', '<BLNK>', 'с', '<BLNK>', 'я', '<BLNK>', 'т', '<BLNK>', 'с', '<BLNK>', 'я', '<BLNK>', ' ', '<BLNK>', 'ж', '<BLNK>', 'е', '<BLNK>', 'н', '<BLNK>', 'с', '<BLNK>', 'к', '<BLNK>', 'и', '<BLNK>', 'е', '<BLNK>', ' ', '<BLNK>', 'в', '<BLNK>', 'о', '<BLNK>', 'с', '<BLNK>', 'к', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', 'ц', '<BLNK>', 'а', '<BLNK>', 'н', '<BLNK>', 'и', '<BLNK>', 'я', '<BLNK>', ' ', '<BLNK>', '–', '<BLNK>', ' ', '<BLNK>', 'с', '<BLNK>', 'п', '<BLNK>', 'р', '<BLNK>', 'о', '<BLNK>', 'с', '<BLNK>', 'и', '<BLNK>', ' ', '<BLNK>', 'н', '<BLNK>', 'а', '<BLNK>', 'с', '<BLNK>', 'ч', '<BLNK>', 'е', '<BLNK>', 'т', '<BLNK>', ' ', '<BLNK>', 'к', '<BLNK>', 'о', '<BLNK>', 'с', '<BLNK>', 'м', '<BLNK>', 'е', '<BLNK>', 'т', '<BLNK>', 'и', '<BLNK>', 'к', '<BLNK>', 'и', '<BLNK>', '!', '<BLNK>', '.', '<BLNK>', '.', '<BLNK>', ' ', '<BLNK>', 'и', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>']['<BLNK>', 'п', '<BLNK>', 'р', '<BLNK>', 'и', '<BLNK>', 'ч', '<BLNK>', 'е', '<BLNK>', 'м', '<BLNK>', ' ', '<BLNK>', 'о', '<BLNK>', 'д', '<BLNK>', 'е', '<BLNK>', 'р', '<BLNK>', 'ж', '<BLNK>', 'и', '<BLNK>', 'м', '<BLNK>', 'о', '<BLNK>', 'г', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'е', '<BLNK>', 'д', '<BLNK>', 'и', '<BLNK>', 'н', '<BLNK>', 'с', '<BLNK>', 'т', '<BLNK>', 'в', '<BLNK>', 'е', '<BLNK>', 'н', '<BLNK>', 'н', '<BLNK>', 'о', '<BLNK>', 'й', '<BLNK>', ' ', '<BLNK>', 'ц', '<BLNK>', 'е', '<BLNK>', 'л', '<BLNK>', 'ь', '<BLNK>', 'ю', '<BLNK>', ' ', '<BLNK>', '–', '<BLNK>', ' ', '<BLNK>', 'к', '<BLNK>', 'а', '<BLNK>', 'к', '<BLNK>', ' ', '<BLNK>', 'м', '<BLNK>', 'о', '<BLNK>', 'ж', '<BLNK>', 'н', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'с', '<BLNK>', 'к', '<BLNK>', 'о', '<BLNK>', 'р', '<BLNK>', 'е', '<BLNK>', 'е', '<BLNK>', ' ', '<BLNK>', 'д', '<BLNK>', 'о', '<BLNK>', 'б', '<BLNK>', 'и', '<BLNK>', 'т', '<BLNK>', 'ь', '<BLNK>', 'с', '<BLNK>', 'я', '<BLNK>', ' ', '<BLNK>', 'р', '<BLNK>', 'а', '<BLNK>', 'з', '<BLNK>', 'о', '<BLNK>', 'б', '<BLNK>', 'л', '<BLNK>', 'а', '<BLNK>', 'ч', '<BLNK>', 'е', '<BLNK>', 'н', '<BLNK>', 'и', '<BLNK>', 'я', '<BLNK>', '.', '<BLNK>']
#
#  [!] Character '–' not found in the vocabulary. Discarding it. [!] Character '–' not found in the vocabulary. Discarding it.
#
# ['<BLNK>', '«', '<BLNK>', 'в', '<BLNK>', ' ', '<BLNK>', 'н', '<BLNK>', 'е', '<BLNK>', 'у', '<BLNK>', 'с', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', 'й', '<BLNK>', 'ч', '<BLNK>', 'и', '<BLNK>', 'в', '<BLNK>', 'о', '<BLNK>', 'с', '<BLNK>', 'т', '<BLNK>', 'и', '<BLNK>', ' ', '<BLNK>', 'д', '<BLNK>', 'в', '<BLNK>', 'и', '<BLNK>', 'ж', '<BLNK>', 'е', '<BLNK>', 'н', '<BLNK>', 'и', '<BLNK>', 'е', '<BLNK>', '!', '<BLNK>', '»', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'и', '<BLNK>', 'с', '<BLNK>', 'а', '<BLNK>', 'л', '<BLNK>', ' ', '<BLNK>', 'з', '<BLNK>', 'н', '<BLNK>', 'а', '<BLNK>', 'м', '<BLNK>', 'е', '<BLNK>', 'н', '<BLNK>', 'и', '<BLNK>', 'т', '<BLNK>', 'ы', '<BLNK>', 'й', '<BLNK>', ' ', '<BLNK>', 'т', '<BLNK>', 'е', '<BLNK>', 'о', '<BLNK>', 'р', '<BLNK>', 'е', '<BLNK>', 'т', '<BLNK>', 'и', '<BLNK>', 'к', '<BLNK>', ' ', '<BLNK>', 'м', '<BLNK>', 'у', '<BLNK>', 'з', '<BLNK>', 'ы', '<BLNK>', 'к', '<BLNK>', 'и', '<BLNK>', ' ', '<BLNK>', 'ч', '<BLNK>', 'е', '<BLNK>', 'р', '<BLNK>', 'н', '<BLNK>', 'и', '<BLNK>', '…', '<BLNK>']['<BLNK>', 'м', '<BLNK>', 'н', '<BLNK>', 'е', '<BLNK>', ' ', '<BLNK>', 'к', '<BLNK>', 'а', '<BLNK>', 'ж', '<BLNK>', 'е', '<BLNK>', 'т', '<BLNK>', 'с', '<BLNK>', 'я', '<BLNK>', ',', '<BLNK>', ' ', '<BLNK>', 'н', '<BLNK>', 'а', '<BLNK>', 'п', '<BLNK>', 'р', '<BLNK>', 'и', '<BLNK>', 'м', '<BLNK>', 'е', '<BLNK>', 'р', '<BLNK>', ',', '<BLNK>', ' ', '<BLNK>', 'ч', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'в', '<BLNK>', 'с', '<BLNK>', 'е', '<BLNK>', ' ', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', 'л', '<BLNK>', 'с', '<BLNK>', 'т', '<BLNK>', 'ы', '<BLNK>', 'е', '<BLNK>', ' ', '<BLNK>', 'ж', '<BLNK>', 'е', '<BLNK>', 'н', '<BLNK>', 'щ', '<BLNK>', 'и', '<BLNK>', 'н', '<BLNK>', 'ы', '<BLNK>', ' ', '<BLNK>', '–', '<BLNK>', ' ', '<BLNK>', 'л', '<BLNK>', 'г', '<BLNK>', 'у', '<BLNK>', 'н', '<BLNK>', 'ь', '<BLNK>', 'и', '<BLNK>', '.', '<BLNK>']['<BLNK>', 'х', '<BLNK>', 'о', '<BLNK>', 'т', '<BLNK>', 'я', '<BLNK>', ' ', '<BLNK>', 'э', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'у', '<BLNK>', 'ж', '<BLNK>', 'е', '<BLNK>', ' ', '<BLNK>', 'д', '<BLNK>', 'р', '<BLNK>', 'у', '<BLNK>', 'г', '<BLNK>', 'а', '<BLNK>', 'я', '<BLNK>', ' ', '<BLNK>', 'т', '<BLNK>', 'е', '<BLNK>', 'м', '<BLNK>', 'а', '<BLNK>', '…', '<BLNK>', ' ', '<BLNK>', 'в', '<BLNK>', ' ', '<BLNK>', 'о', '<BLNK>', 'б', '<BLNK>', 'щ', '<BLNK>', 'е', '<BLNK>', 'м', '<BLNK>', ',', '<BLNK>', ' ', '<BLNK>', 'с', '<BLNK>', ' ', '<BLNK>', 'э', '<BLNK>', 'с', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', 'н', '<BLNK>', 'с', '<BLNK>', 'к', '<BLNK>', 'и', '<BLNK>', 'м', '<BLNK>', ' ', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', 'б', '<BLNK>', 'е', '<BLNK>', 'р', '<BLNK>', 'а', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', 'з', '<BLNK>', 'м', '<BLNK>', 'о', '<BLNK>', 'м', '<BLNK>', ' ', '<BLNK>', 'б', '<BLNK>', 'ы', '<BLNK>', 'л', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'о', '<BLNK>', 'к', '<BLNK>', 'о', '<BLNK>', 'н', '<BLNK>', 'ч', '<BLNK>', 'е', '<BLNK>', 'н', '<BLNK>', 'о', '<BLNK>', '.', '<BLNK>']
# ['<BLNK>', '–', '<BLNK>', ' ', '<BLNK>', 'ч', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'т', '<BLNK>', 'а', '<BLNK>', 'к', '<BLNK>', 'о', '<BLNK>', 'е', '<BLNK>', '?', '<BLNK>', ' ', '<BLNK>', '–', '<BLNK>', ' ', '<BLNK>', 'с', '<BLNK>', 'п', '<BLNK>', 'р', '<BLNK>', 'о', '<BLNK>', 'с', '<BLNK>', 'и', '<BLNK>', 'л', '<BLNK>', ' ', '<BLNK>', 'х', '<BLNK>', 'у', '<BLNK>', 'р', '<BLNK>', 'и', '<BLNK>', 'е', '<BLNK>', 'в', '<BLNK>', '.', '<BLNK>', ' ', '<BLNK>', '–', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'е', '<BLNK>', 'р', '<BLNK>', 'е', '<BLNK>', 'ж', '<BLNK>', 'и', '<BLNK>', 'в', '<BLNK>', 'а', '<BLNK>', 'ю', '<BLNK>', '…', '<BLNK>', ' ', '<BLNK>', '–', '<BLNK>', ' ', '<BLNK>', 'о', '<BLNK>', 'т', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', 'ч', '<BLNK>', 'н', '<BLNK>', 'о', '<BLNK>', '.', '<BLNK>', ' ', '<BLNK>', 'э', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'н', '<BLNK>', 'а', '<BLNK>', 'з', '<BLNK>', 'ы', '<BLNK>', 'в', '<BLNK>', 'а', '<BLNK>', 'е', '<BLNK>', 'т', '<BLNK>', 'с', '<BLNK>', 'я', '<BLNK>', ' ', '<BLNK>', '–', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'е', '<BLNK>', 'р', '<BLNK>', 'е', '<BLNK>', 'в', '<BLNK>', 'о', '<BLNK>', 'п', '<BLNK>', 'л', '<BLNK>', 'о', '<BLNK>', 'щ', '<BLNK>', 'е', '<BLNK>', 'н', '<BLNK>', 'и', '<BLNK>', 'е', '<BLNK>', '…', '<BLNK>']
#  [!] Character '…' not found in the vocabulary. Discarding it.
#
#  [!] Character '–' not found in the vocabulary. Discarding it.
#  [!] Character '…' not found in the vocabulary. Discarding it. [!] Character '…' not found in the vocabulary. Discarding it.
#
#
# ['<BLNK>', 'п', '<BLNK>', 'ы', '<BLNK>', 'т', '<BLNK>', 'а', '<BLNK>', 'л', '<BLNK>', 'а', '<BLNK>', 'с', '<BLNK>', 'ь', '<BLNK>', ' ', '<BLNK>', 'ч', '<BLNK>', 'и', '<BLNK>', 'т', '<BLNK>', 'а', '<BLNK>', 'т', '<BLNK>', 'ь', '<BLNK>', ' ', '<BLNK>', 'в', '<BLNK>', ' ', '<BLNK>', 'о', '<BLNK>', 'р', '<BLNK>', 'и', '<BLNK>', 'г', '<BLNK>', 'и', '<BLNK>', 'н', '<BLNK>', 'а', '<BLNK>', 'л', '<BLNK>', 'е', '<BLNK>', ' ', '<BLNK>', 'х', '<BLNK>', 'е', '<BLNK>', 'м', '<BLNK>', 'и', '<BLNK>', 'н', '<BLNK>', 'г', '<BLNK>', 'у', '<BLNK>', 'э', '<BLNK>', 'я', '<BLNK>', '.', '<BLNK>', ' ', '<BLNK>', 'е', '<BLNK>', 'е', '<BLNK>', ' ', '<BLNK>', 'р', '<BLNK>', 'о', '<BLNK>', 'д', '<BLNK>', 'и', '<BLNK>', 'т', '<BLNK>', 'е', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', ' ', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'ч', '<BLNK>', 'е', '<BLNK>', 'м', '<BLNK>', '‑', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'д', '<BLNK>', 'о', '<BLNK>', 'г', '<BLNK>', 'а', '<BLNK>', 'д', '<BLNK>', 'ы', '<BLNK>', 'в', '<BLNK>', 'а', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', 'с', '<BLNK>', 'ь', '<BLNK>', ',', '<BLNK>', ' ', '<BLNK>', 'н', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'м', '<BLNK>', 'о', '<BLNK>', 'л', '<BLNK>', 'ч', '<BLNK>', 'а', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', '.', '<BLNK>']['<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', 'г', '<BLNK>', 'д', '<BLNK>', 'а', '<BLNK>', ' ', '<BLNK>', 'я', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'р', '<BLNK>', 'и', '<BLNK>', 'п', '<BLNK>', 'о', '<BLNK>', 'д', '<BLNK>', 'н', '<BLNK>', 'и', '<BLNK>', 'м', '<BLNK>', 'а', '<BLNK>', 'ю', '<BLNK>', 'с', '<BLNK>', 'ь', '<BLNK>', ' ', '<BLNK>', '–', '<BLNK>', ' ', '<BLNK>', 'б', '<BLNK>', 'л', '<BLNK>', 'е', '<BLNK>', 'д', '<BLNK>', 'н', '<BLNK>', 'ы', '<BLNK>', 'й', '<BLNK>', ',', '<BLNK>', ' ', '<BLNK>', 'о', '<BLNK>', 'б', '<BLNK>', 'е', '<BLNK>', 'с', '<BLNK>', 'к', '<BLNK>', 'р', '<BLNK>', 'о', '<BLNK>', 'в', '<BLNK>', 'л', '<BLNK>', 'е', '<BLNK>', 'н', '<BLNK>', 'н', '<BLNK>', 'ы', '<BLNK>', 'й', '<BLNK>', ',', '<BLNK>', ' ', '<BLNK>', 'х', '<BLNK>', 'у', '<BLNK>', 'д', '<BLNK>', 'о', '<BLNK>', 'й', '<BLNK>', ',', '<BLNK>', ' ', '<BLNK>', 'и', '<BLNK>', ' ', '<BLNK>', 'г', '<BLNK>', 'о', '<BLNK>', 'в', '<BLNK>', 'о', '<BLNK>', 'р', '<BLNK>', 'ю', '<BLNK>', ' ', '<BLNK>', '–', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'о', '<BLNK>', 'с', '<BLNK>', 'т', '<BLNK>', 'а', '<BLNK>', 'в', '<BLNK>', 'ь', '<BLNK>', 'т', '<BLNK>', 'е', '<BLNK>', ' ', '<BLNK>', 'т', '<BLNK>', 'р', '<BLNK>', 'о', '<BLNK>', 'й', '<BLNK>', 'к', '<BLNK>', 'у', '<BLNK>', '!', '<BLNK>']
#
#  [!] Character '‑' not found in the vocabulary. Discarding it. [!] Character '–' not found in the vocabulary. Discarding it.
#
# ['<BLNK>', 'э', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'к', '<BLNK>', 'а', '<BLNK>', 'к', '<BLNK>', 'а', '<BLNK>', 'я', '<BLNK>', '‑', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'о', '<BLNK>', 'р', '<BLNK>', 'г', '<BLNK>', 'а', '<BLNK>', 'н', '<BLNK>', 'и', '<BLNK>', 'ч', '<BLNK>', 'е', '<BLNK>', 'с', '<BLNK>', 'к', '<BLNK>', 'а', '<BLNK>', 'я', '<BLNK>', ' ', '<BLNK>', 'с', '<BLNK>', 'п', '<BLNK>', 'о', '<BLNK>', 'с', '<BLNK>', 'о', '<BLNK>', 'б', '<BLNK>', 'н', '<BLNK>', 'о', '<BLNK>', 'с', '<BLNK>', 'т', '<BLNK>', 'ь', '<BLNK>', ' ', '<BLNK>', 'к', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'е', '<BLNK>', 'р', '<BLNK>', 'е', '<BLNK>', 'в', '<BLNK>', 'о', '<BLNK>', 'п', '<BLNK>', 'л', '<BLNK>', 'о', '<BLNK>', 'щ', '<BLNK>', 'е', '<BLNK>', 'н', '<BLNK>', 'и', '<BLNK>', 'ю', '<BLNK>', '.', '<BLNK>', ' ', '<BLNK>', 'к', '<BLNK>', 'о', '<BLNK>', 'р', '<BLNK>', 'о', '<BLNK>', 'ч', '<BLNK>', 'е', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'е', '<BLNK>', 'р', '<BLNK>', 'е', '<BLNK>', 'в', '<BLNK>', 'о', '<BLNK>', 'д', '<BLNK>', 'ы', '<BLNK>', ' ', '<BLNK>', '–', '<BLNK>', ' ', '<BLNK>', 'э', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'с', '<BLNK>', 'у', '<BLNK>', 'д', '<BLNK>', 'ь', '<BLNK>', 'б', '<BLNK>', 'а', '<BLNK>', '.', '<BLNK>']
#  [!] Character '‑' not found in the vocabulary. Discarding it.['<BLNK>', 'х', '<BLNK>', 'о', '<BLNK>', 'т', '<BLNK>', 'е', '<BLNK>', 'л', '<BLNK>', 'о', '<BLNK>', 'с', '<BLNK>', 'ь', '<BLNK>', ' ', '<BLNK>', 'б', '<BLNK>', 'ы', '<BLNK>', '…', '<BLNK>', ' ', '<BLNK>', 'е', '<BLNK>', 'с', '<BLNK>', 'л', '<BLNK>', 'и', '<BLNK>', ' ', '<BLNK>', 'э', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'в', '<BLNK>', 'о', '<BLNK>', 'з', '<BLNK>', 'м', '<BLNK>', 'о', '<BLNK>', 'ж', '<BLNK>', 'н', '<BLNK>', 'о', '<BLNK>', '…', '<BLNK>', ' ', '<BLNK>', 'к', '<BLNK>', 'о', '<BLNK>', 'р', '<BLNK>', 'о', '<BLNK>', 'ч', '<BLNK>', 'е', '<BLNK>', ',', '<BLNK>', ' ', '<BLNK>', 'в', '<BLNK>', 'а', '<BLNK>', 'ш', '<BLNK>', 'е', '<BLNK>', ' ', '<BLNK>', 'м', '<BLNK>', 'н', '<BLNK>', 'е', '<BLNK>', 'н', '<BLNK>', 'и', '<BLNK>', 'е', '<BLNK>', '…', '<BLNK>', ' ', '<BLNK>', 'б', '<BLNK>', 'у', '<BLNK>', 'к', '<BLNK>', 'в', '<BLNK>', 'а', '<BLNK>', 'л', '<BLNK>', 'ь', '<BLNK>', 'н', '<BLNK>', 'о', '<BLNK>', ' ', '<BLNK>', 'в', '<BLNK>', ' ', '<BLNK>', 'д', '<BLNK>', 'в', '<BLNK>', 'у', '<BLNK>', 'х', '<BLNK>', ' ', '<BLNK>', 'с', '<BLNK>', 'л', '<BLNK>', 'о', '<BLNK>', 'в', '<BLNK>', 'а', '<BLNK>', 'х', '<BLNK>', '…', '<BLNK>']
#
#  [!] Character '…' not found in the vocabulary. Discarding it.
# ['<BLNK>', '–', '<BLNK>', ' ', '<BLNK>', 'к', '<BLNK>', '‑', '<BLNK>', 'а', '<BLNK>', '‑', '<BLNK>', 'а', '<BLNK>', '‑', '<BLNK>', 'к', '<BLNK>', 'э', '<BLNK>', 'м', '<BLNK>', '!', '<BLNK>', ' ', '<BLNK>', 'а', '<BLNK>', 'б', '<BLNK>', 'а', '<BLNK>', 'н', '<BLNK>', 'а', '<BLNK>', 'м', '<BLNK>', 'а', '<BLNK>', 'т', '<BLNK>', '!', '<BLNK>', '.', '<BLNK>', '.', '<BLNK>', ' ', '<BLNK>', 'г', '<BLNK>', 'л', '<BLNK>', 'а', '<BLNK>', 'в', '<BLNK>', 'а', '<BLNK>', ' ', '<BLNK>', 'т', '<BLNK>', 'р', '<BLNK>', 'е', '<BLNK>', 'т', '<BLNK>', 'ь', '<BLNK>', 'я', '<BLNK>', ' ', '<BLNK>', 'д', '<BLNK>', 'я', '<BLNK>', 'д', '<BLNK>', 'я', '<BLNK>', ' ', '<BLNK>', 'р', '<BLNK>', 'о', '<BLNK>', 'м', '<BLNK>', 'а', '<BLNK>', 'н', '<BLNK>', ' ', '<BLNK>', 'с', '<BLNK>', 'т', '<BLNK>', 'е', '<BLNK>', 'п', '<BLNK>', 'а', '<BLNK>', 'н', '<BLNK>', 'о', '<BLNK>', 'в', '<BLNK>', 'и', '<BLNK>', 'ч', '<BLNK>', ' ', '<BLNK>', 'л', '<BLNK>', 'ю', '<BLNK>', 'б', '<BLNK>', 'и', '<BLNK>', 'л', '<BLNK>', ' ', '<BLNK>', 'п', '<BLNK>', 'о', '<BLNK>', 'в', '<BLNK>', 'т', '<BLNK>', 'о', '<BLNK>', 'р', '<BLNK>', 'я', '<BLNK>', 'т', '<BLNK>', 'ь', '<BLNK>']
#  [!] Character '‑' not found in the vocabulary. Discarding it.
#  ! Run is removed from /content/vits_vctk-March-05-2023_07+59PM-0000000
#  | > Synthesizing test sentences.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/trainer/trainer.py", line 1591, in fit
#     self._fit()
#   File "/usr/local/lib/python3.8/dist-packages/trainer/trainer.py", line 1548, in _fit
#     self.test_run()
#   File "/usr/local/lib/python3.8/dist-packages/trainer/trainer.py", line 1466, in test_run
#     test_outputs = self.model.test_run(self.training_assets)
#   File "/usr/local/lib/python3.8/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/TTS/tts/models/vits.py", line 1438, in test_run
#     aux_inputs = self.get_aux_input_from_test_sentences(s_info)
#   File "/usr/local/lib/python3.8/dist-packages/TTS/tts/models/vits.py", line 1409, in get_aux_input_from_test_sentences
#     speaker_id = self.speaker_manager.name_to_id[speaker_name]
# AttributeError: 'NoneType' object has no attribute 'name_to_id'
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# cleanup "output" from cache
import shutil
shutil.rmtree("./phoneme_cache")
